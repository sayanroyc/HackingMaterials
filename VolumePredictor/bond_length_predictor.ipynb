# %% [markdown]
# ## Imports

# %%
from pymongo import MongoClient
client = MongoClient()
db = client.structure_sets

from IPython.display import display
import pandas as pd
pd.options.display.max_rows = 9999

from pymatgen import Element, Structure
import math
import time
import pprint
import math
import warnings
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
# setup our parallel processing units..
import ipyparallel as ipp
c = ipp.Client()
print c.ids
# dview = c[:]
lview = c.load_balanced_view()

# with c[:].sync_imports():
#     from pymatgen import Structure
#     from matminer.learners.volume_predictor import VolumePredictor
#     from vp_funcs import get_id_serial_f
# Out:
# [0, 1, 2, 3]
# /Users/sayan/miniconda2/envs/py2/lib/python2.7/site-packages/ipyparallel/client/client.py:442: RuntimeWarning:
#             Controller appears to be listening on localhost, but not on this machine.
#             If this is true, you should specify Client(...,sshserver='you@198.128.197.28')
#             or instruct your controller to listen on an external IP.
#   RuntimeWarning)

# %% [markdown]
# ## Define bond length prediction functions

# %%
def predict_bond_length(structure):
    cutoff=4
    ionic_factor = 0.30
    
    smallest_dist = None
    smallest_expected_dist = None
    smallest_ratio = None
    smallest_e1 = None
    smallest_e2 = None
    
    ionic_mix = min(np.std(get_pymatgen_descriptor(structure.composition, 'X')) * ionic_factor, 1)
    
    for site in structure:
        el1 = site.specie

        if el1.atomic_radius:
            r1 = el1.average_ionic_radius * ionic_mix + \
                 el1.atomic_radius * (1-ionic_mix) if el1.average_ionic_radius else el1.atomic_radius
                
            neighbors = structure.get_neighbors(site, el1.atomic_radius + cutoff)
            
            for site2, dist in neighbors:
                el2 = site2.specie
                
                if el2.atomic_radius or el2.average_ionic_radius:
                    bond_name = '-'.join(sorted([el1.symbol, el2.symbol]))
                    if bond_name in bonds.keys():
                        expected_dist = bonds[bond_name]['estimates'][-1]
                    else:
                        expected_dist = el1.atomic_radius + el2.atomic_radius
                        r2 = el2.average_ionic_radius * ionic_mix + \
                             el2.atomic_radius * (1-ionic_mix) if el2.average_ionic_radius else el2.atomic_radius

                    if not smallest_ratio or dist/expected_dist < smallest_ratio:
                        smallest_dist = dist
                        smallest_expected_dist = expected_dist
                        smallest_ratio = dist/expected_dist
                        smallest_e1 = el1
                        smallest_e2 = el2
        else:
            warnings.warn("VolumePredictor: no atomic radius data for "
                          "{}".format(el1))

    if smallest_ratio is None:
        return None
            
    volume_factor = (1/smallest_ratio)**3
            
    return {'name': structure.composition.reduced_formula, 'actual_volume': structure.volume,
            'predicted_volume': structure.volume * volume_factor, 'num_atoms': structure.composition.num_atoms,
            'worst_predicted_bond': '-'.join(sorted([smallest_e1.symbol, smallest_e2.symbol])),
            'actual_distance': smallest_dist, 'expected_distance': smallest_expected_dist}

# %%
def get_worst_bond_length_prediction(inp):
    doc = inp[0]
    bonds = inp[1]
#     bonds = {}
    
    import numpy as np
    from matminer.descriptors.composition_features import get_pymatgen_descriptor
    from pymatgen import Element, Structure
    import warnings
    structure = Structure.from_dict(doc)
    cutoff=4
    ionic_factor = 0.30
    
    smallest_dist = None
    smallest_expected_dist = None
    smallest_ratio = None
    smallest_e1 = None
    smallest_e2 = None
    
    ionic_mix = min(np.std(get_pymatgen_descriptor(structure.composition, 'X')) * ionic_factor, 1)
    
    for site in structure:
        el1 = site.specie

        if el1.atomic_radius:
            r1 = el1.average_ionic_radius * ionic_mix + \
                 el1.atomic_radius * (1-ionic_mix) if el1.average_ionic_radius else el1.atomic_radius
                
            neighbors = structure.get_neighbors(site, el1.atomic_radius + cutoff)
            
            for site2, dist in neighbors:
                el2 = site2.specie
                

                if el2.atomic_radius:
                    r2 = el2.average_ionic_radius * ionic_mix + \
                         el2.atomic_radius * (1-ionic_mix) if el2.average_ionic_radius else el2.atomic_radius
                
                    bond_name = '-'.join(sorted([el1.symbol, el2.symbol]))
                    if bond_name in bonds:
                        expected_dist = bonds[bond_name]['estimates'][-1]
                    else:
                        expected_dist = float(r1+r2)

                    if not smallest_ratio or dist/expected_dist < smallest_ratio:
                        smallest_dist = dist
                        smallest_expected_dist = expected_dist
                        smallest_ratio = dist/expected_dist
                        smallest_e1 = el1
                        smallest_e2 = el2
        else:
            warnings.warn("VolumePredictor: no atomic radius data for "
                          "{}".format(el1))

    if smallest_ratio is None:
        print structure.composition.reduced_formula, doc['_id'], 'FAILED'
        return {'name':structure.composition.reduced_formula, '_id':doc['_id'],
                'status': 'FAILED'}
    
    volume_factor = (1/smallest_ratio)**3
            
    return {'name': structure.composition.reduced_formula, 'actual_volume': structure.volume,
            'predicted_volume': structure.volume * volume_factor, 'num_atoms': structure.composition.num_atoms,
            'worst_predicted_bond': '-'.join(sorted([smallest_e1.symbol, smallest_e2.symbol])),
            'actual_distance': smallest_dist, 'expected_distance': smallest_expected_dist,
            '_id':doc['_id']}

# %%
def create_bonds_dict(bl_pred_0):
    for b in bl_pred_0['worst_predicted_bond'].unique():
        if b not in bonds:
            bonds[b]={'mp_values':[], 'estimates':[]}

def get_mp_values(c):
    if c['worst_predicted_bond'] in bonds:
        bonds[c['worst_predicted_bond']]['mp_values'].append(c['actual_distance'])
    else:
        print c['worst_predicted_bond'], 'DNE. Creating entry in bonds dict..'
        bonds[c['worst_predicted_bond']]={'mp_values':[c['actual_distance']], 'estimates':[]}

def get_worst_predicted_bonds_avg_minus_median():
    bond_estimate_data = []
    percent_to_return = 0.1
    num_bonds_to_change = int(percent_to_return*len(bonds))
    for b in bonds:
        b_median = np.median(bonds[b]['mp_values'])
        b_est = bonds[b]['estimates'][-1]
        b_dist = abs(b_median-b_est)

        bond_estimate_data.append({'bond_name':b, 'median-estimate': b_dist})

    bond_estimate_data_df = pd.DataFrame(bond_estimate_data)

    return bond_estimate_data_df.sort_values('median-estimate',ascending=False)[:num_bonds_to_change]['bond_name'].tolist()
        
def get_worst_predicted_bonds_avg_score(bl_pred_0):
    bond_estimate_data = []
    percent_to_return = 0.1
    num_bonds_to_change = int(percent_to_return*len(bonds))
    for b in bl_pred_0['worst_predicted_bond'].unique():
        df =  bl_pred_0[bl_pred_0['worst_predicted_bond']==b]
        mean_score = df['score'].mean()
        bond_estimate_data.append({'bond_name':b, 'mean_score': np.mean(mean_score)})

    bond_estimate_data_df = pd.DataFrame(bond_estimate_data)

    return bond_estimate_data_df.sort_values('mean_score',ascending=False)[:num_bonds_to_change]['bond_name'].tolist()
    
    
def update_estimates(bl_pred_df, iter_num, bonds_to_update,weight=0.5):
    for b in bonds_to_update:
        if len(bonds[b]['estimates'])<iter_num+2: # after iteration 0, we want at most 2 estimate entries (old prediction and new)
            if len(bonds[b]['estimates']) == 0: # first iteration estimate is always the OG prediction
                df = bl_pred_df[bl_pred_df['worst_predicted_bond']==b]
                new_estimate = df['expected_distance'].mean()
            else:
                new_estimate = weight*(np.median(bonds[b]['mp_values'])) + (1-weight)*(bonds[b]['estimates'][-1])
                
            bonds[b]['estimates'].append(new_estimate)

# %%
def score(c, pred_vol='predicted_volume', act_vol='actual_volume', num_atoms='num_atoms'):
    """
    Found that the % error isn't a great measurement of error in our case.
    Our worst cases occur the farthest away from the optimal line (y=x),
    so define a function that finds distance between the optimal line and the point.
    
        Args:
        c (Series) : Series corresponding to a single structure
        structures_path (str) : file path to set of structures
        predictor (str) : string defining which predictor to use - 
                            "mm" : mat miner
                            "dev" : dev predictor
                            "okeeffe" : O'Keefffe predictor
        print_info (bool) : set to True to print out smallest ratio info for a structure
                            
    Returns:
        a float value of the distance away from the optimal line
    """
    
    # define the optimal line here using two points
    # line is y = x
    x1 = 0
    y1 = 0
    x2 = 100
    y2 = 100
    
    # set x3, y3 as the point
    try:
        x3 = c[pred_vol]/c[num_atoms]
        y3 = c[act_vol]/c[num_atoms]
    except:
        sys.exit("Error: specified column does not exist")
        
        
    # run the actual calculation here..
    px = x2-x1
    py = y2-y1

    temp = px*px + py*py

    u =  ((x3 - x1) * px + (y3 - y1) * py) / float(temp)

    if u > 1:
        u = 1
    elif u < 0:
        u = 0

    x = x1 + u * px
    y = y1 + u * py

    dx = x - x3
    dy = y - y3

    dist = math.sqrt(dx*dx + dy*dy)

    return dist


def score_test(x1, y1, x2, y2, x3,y3):
    px = x2-x1
    py = y2-y1

    temp = px*px + py*py

    u =  ((x3 - x1) * px + (y3 - y1) * py) / float(temp)

    if u > 1:
        u = 1
    elif u < 0:
        u = 0

    x = x1 + u * px
    y = y1 + u * py

    dx = x - x3
    dy = y - y3

    dist = math.sqrt(dx*dx + dy*dy)

    return dist


def percent_error_df(c, pred_vol='predicted_volume', act_vol='actual_volume', num_atoms='num_atoms'):
    return percent_error(c['predicted_volume']/c[num_atoms], c['actual_volume']/c[num_atoms])
    

def percent_error(calculcated, actual):
    return abs(calculcated+actual)/actual*100

score_test(0,0,100,100,45,50)
# Out:
# 3.5355339059327378

# %% [markdown]
# ## MAIN

# %%
"""
bonds is a dictionary organized in the following manner:
    key: 'element1-element2' ex. 'C-Cl'
    'mp_values': array of values calculated from the structures in Materials Project
    'estimates': array of the last estimated value used (entry 0 should be r_atomic+r_atomic)
"""
bonds = {}

# %%
# For each structure, get the worst bond length estimate
# The estimate is made from the value found in the bonds dictionary
# If it is not there, set bond length prediction to r_atomic_e1 + r_atomic_e2
# DON'T MAKE THIS MISTAKE AGAIN :(
bonds = {}
bond_length_predictions = []
bl_pred_dfs = []
scores = []
bonds_updated_this_iter = []

# %%
"""

Main block. This section runs through all of the Materials Project database, estimating the bond lengths for
each structure, and storing the worst estimate in bond_length_predictions[iter_index]. After each iteration
through the Materials Proejct database, updates the n worst performing bond by moving the estimate closer
to the median of the values found.

Run this section after setting the number of iterations and how many bonds to change per iteration.

"""


cursor = db.mp_final.find()

init_iter = 1
num_iter = 1
num_bonds_to_change_per_iter = 10
weight = 0.5
weight_decay_per_iter = 0.9


for i in range (init_iter, init_iter+num_iter):
    print '\n################### ROUND', i, '#######################'
    bond_length_predictions.append([])
#     num_processed = 0
#     new_bonds_added_this_iter = []

    lim = 1000
    iter_num = 0
    d = []
    print len(bond_length_predictions[i]), 'structures processed'
    while len(bond_length_predictions[i]) < cursor.count():
        temp_cursor = cursor.clone()
        temp_cursor.skip(lim*iter_num)
        temp_cursor.limit(lim)
        d = lview.map_sync(get_worst_bond_length_prediction, [[doc,bonds] for doc in temp_cursor])
        bond_length_predictions[i] += d
        iter_num+=1
        print len(bond_length_predictions[i]), 'structures processed'

    print 'making dataframe'
    cols = ['name', 'worst_predicted_bond', 'expected_distance', 'actual_distance', 'predicted_volume', 'actual_volume',
        'num_atoms', '_id']
    bl_pred_dfs.append(pd.DataFrame(bond_length_predictions[i], columns=cols))


# Mess with the scores stuff 
#     if scores[-1] < score_this_iter:
#         print 'Optimal score found at iteration', i
#         print 'Print "scores" for list of values'
#         break
#     else:
#         scores.append(score_this_iter)


    print 'calculating score'
    bl_pred_dfs[i]['score'] = bl_pred_dfs[i].apply(score, args=('predicted_volume','actual_volume','num_atoms'), axis=1)
    score_this_iter = bl_pred_dfs[i]['score'].mean()    
    scores.append(score_this_iter)

    print 'initializing bonds dict (iteration 0). initial estimate original vol predictor'
    if i == 0: # initialization of bonds dict estimates
        # create a dictionary bonds
        print 'creating bonds dict'
        create_bonds_dict(bl_pred_dfs[0])
        # gets all of the materials project data for bond lengths and puts it in 'mp_values'
        print 'collecting Materials Project bond lengths'
        bl_pred_dfs[i].apply(get_mp_values,axis=1)
        # initialize our first estimate
        print 'initializing estimates'
        update_estimates(bl_pred_dfs[i], i, bonds.keys(), weight)

    
    # if a new bond shows up, add it to the dict!
    for b in bl_pred_dfs[i]['worst_predicted_bond'].unique():
        if b not in bonds:
            bonds[b]={'mp_values':[], 'estimates':[]}
            df =  bl_pred_dfs[i][bl_pred_dfs[i]['worst_predicted_bond']==b]
            bonds[b]['mp_values'] = df['actual_distance'].tolist()
            new_estimate = df['expected_distance'].mean()
            bonds[b]['estimates'] = [new_estimate]
            print 'NEW BOND', b, 'added to bonds dict'
    
    print 'updating bonds dict and adding new estimates for 10%'
    bonds_updated_this_iter.append(get_worst_predicted_bonds()) # get back a list of bond length estimates updated
    update_estimates(bl_pred_dfs[i], i, bonds_updated_this_iter[i], weight)
    weight = weight * weight_decay_per_iter
# Out:
# ################### ROUND 0 #######################
# 67466 structures processed
# making dataframe
# calculating score
# initializing bonds dict (iteration 0). initial estimate original vol predictor
# updating bonds dict and adding new estimates for 10%
#
# ################### ROUND 1 #######################
# 0 structures processed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-e0d98ea2a00f> in <module>()
#      34         temp_cursor.skip(lim*iter_num)
#      35         temp_cursor.limit(lim)
# ---> 36         d = lview.map_sync(get_worst_bond_length_prediction, [[doc,bonds] for doc in temp_cursor])
#      37         bond_length_predictions[i] += d
#      38         iter_num+=1
#
# /Users/sayan/miniconda2/envs/py2/lib/python2.7/site-packages/ipyparallel/client/view.pyc in map_sync(self, f, *sequences, **kwargs)
#     340             raise TypeError("map_sync doesn't take a `block` keyword argument.")
#     341         kwargs['block'] = True
# --> 342         return self.map(f,*sequences,**kwargs)
#     343
#     344     def imap(self, f, *sequences, **kwargs):
#
# <decorator-gen-145> in map(self, f, *sequences, **kwargs)
#
# /Users/sayan/miniconda2/envs/py2/lib/python2.7/site-packages/ipyparallel/client/view.pyc in sync_results(f, self, *args, **kwargs)
#      48     self._in_sync_results = True
#      49     try:
# ---> 50         ret = f(self, *args, **kwargs)
#      51     finally:
#      52         self._in_sync_results = False
#
# <decorator-gen-144> in map(self, f, *sequences, **kwargs)
#
# /Users/sayan/miniconda2/envs/py2/lib/python2.7/site-packages/ipyparallel/client/view.pyc in save_ids(f, self, *args, **kwargs)
#      33     n_previous = len(self.client.history)
#      34     try:
# ---> 35         ret = f(self, *args, **kwargs)
#      36     finally:
#      37         nmsgs = len(self.client.history) - n_previous
#
# /Users/sayan/miniconda2/envs/py2/lib/python2.7/site-packages/ipyparallel/client/view.pyc in map(self, f, *sequences, **kwargs)
#    1107
#    1108         pf = ParallelFunction(self, f, block=block, chunksize=chunksize, ordered=ordered)
# -> 1109         return pf.map(*sequences)
#    1110
#    1111     def register_joblib_backend(self, name='ipyparallel', make_default=False):
#
# /Users/sayan/miniconda2/envs/py2/lib/python2.7/site-packages/ipyparallel/client/remotefunction.pyc in map(self, *sequences)
#     283         and mismatched sequence lengths will be padded with None.
#     284         """
# --> 285         return self(*sequences, __ipp_mapping=True)
#     286
#     287 __all__ = ['remote', 'parallel', 'RemoteFunction', 'ParallelFunction']
#
# <decorator-gen-127> in __call__(self, *sequences, **kwargs)
#
# /Users/sayan/miniconda2/envs/py2/lib/python2.7/site-packages/ipyparallel/client/remotefunction.pyc in sync_view_results(f, self, *args, **kwargs)
#      74     view = self.view
#      75     if view._in_sync_results:
# ---> 76         return f(self, *args, **kwargs)
#      77     view._in_sync_results = True
#      78     try:
#
# /Users/sayan/miniconda2/envs/py2/lib/python2.7/site-packages/ipyparallel/client/remotefunction.pyc in __call__(self, *sequences, **kwargs)
#     257             view = self.view if balanced else client[t]
#     258             with view.temp_flags(block=False, **self.flags):
# --> 259                 ar = view.apply(f, *args)
#     260                 ar.owner = False
#     261
#
# /Users/sayan/miniconda2/envs/py2/lib/python2.7/site-packages/ipyparallel/client/view.pyc in apply(self, f, *args, **kwargs)
#     209         ``f(*args, **kwargs)``.
#     210         """
# --> 211         return self._really_apply(f, args, kwargs)
#     212
#     213     def apply_async(self, f, *args, **kwargs):
#
# <decorator-gen-143> in _really_apply(self, f, args, kwargs, block, track, after, follow, timeout, targets, retries)
#
# /Users/sayan/miniconda2/envs/py2/lib/python2.7/site-packages/ipyparallel/client/view.pyc in sync_results(f, self, *args, **kwargs)
#      45     """sync relevant results from self.client to our results attribute."""
#      46     if self._in_sync_results:
# ---> 47         return f(self, *args, **kwargs)
#      48     self._in_sync_results = True
#      49     try:
#
# <decorator-gen-142> in _really_apply(self, f, args, kwargs, block, track, after, follow, timeout, targets, retries)
#
# /Users/sayan/miniconda2/envs/py2/lib/python2.7/site-packages/ipyparallel/client/view.pyc in save_ids(f, self, *args, **kwargs)
#      33     n_previous = len(self.client.history)
#      34     try:
# ---> 35         ret = f(self, *args, **kwargs)
#      36     finally:
#      37         nmsgs = len(self.client.history) - n_previous
#
# /Users/sayan/miniconda2/envs/py2/lib/python2.7/site-packages/ipyparallel/client/view.pyc in _really_apply(self, f, args, kwargs, block, track, after, follow, timeout, targets, retries)
#    1035
#    1036         future = self.client.send_apply_request(self._socket, f, args, kwargs, track=track,
# -> 1037                                 metadata=metadata)
#    1038
#    1039         ar = AsyncResult(self.client, future, fname=getname(f),
#
# /Users/sayan/miniconda2/envs/py2/lib/python2.7/site-packages/ipyparallel/client/client.pyc in send_apply_request(self, socket, f, args, kwargs, metadata, track, ident)
#    1393         bufs = serialize.pack_apply_message(f, args, kwargs,
#    1394             buffer_threshold=self.session.buffer_threshold,
# -> 1395             item_threshold=self.session.item_threshold,
#    1396         )
#    1397
#
# /Users/sayan/miniconda2/envs/py2/lib/python2.7/site-packages/ipyparallel/serialize/serialize.pyc in pack_apply_message(f, args, kwargs, buffer_threshold, item_threshold)
#     164
#     165     arg_bufs = list(chain.from_iterable(
# --> 166         serialize_object(arg, buffer_threshold, item_threshold) for arg in args))
#     167
#     168     kw_keys = sorted(kwargs.keys())
#
# /Users/sayan/miniconda2/envs/py2/lib/python2.7/site-packages/ipyparallel/serialize/serialize.pyc in <genexpr>((arg,))
#     164
#     165     arg_bufs = list(chain.from_iterable(
# --> 166         serialize_object(arg, buffer_threshold, item_threshold) for arg in args))
#     167
#     168     kw_keys = sorted(kwargs.keys())
#
# KeyboardInterrupt:

# %%
# if i == 0: # initialization of bonds dict estimates
#     # create a dictionary bonds
#     create_bonds_dict(bl_pred_dfs[0])
#     # gets all of the materials project data for bond lengths and puts it in 'mp_values'
#     bl_pred_dfs[i].apply(get_mp_values,axis=1)
#     # initialize our first estimate
#   update_estimates(bl_pred_dfs[i], i, bonds.keys(), weight)
len1 = 0
len2 = 0
lenelse= 0
for b in bonds:
    if len(bonds[b]['estimates']) == 1:
        len1 += 1
        #bonds[b]['estimates'] = [bonds[b]['estimates'][0]]
    elif len(bonds[b]['estimates']) == 2:
        len2 += 1
    else:
        lenelse +=1
        
print len1, len2, lenelse

# update_estimates(bl_pred_dfs[i], i, bonds_updated_this_iter[0], weight)

# bonds['F-F']
# display(bl_pred_dfs[0][bl_pred_dfs[0]['worst_predicted_bond']=='Ar-Ar'])
# bond_to_inspect = 'F-F'

# print bonds[bond_to_inspect]
# display(bl_pred_dfs[0][bl_pred_dfs[0]['worst_predicted_bond']==bond_to_inspect])

# bl_pred_dfs[i]['score'] = bl_pred_dfs[i].apply(percent_error_df, args=('predicted_volume','actual_volume','num_atoms'), axis=1)

# test_bonds_to_change_pe = get_worst_predicted_bonds_avg_score(bl_pred_dfs[0])
# test_bonds_to_change == test_bonds_to_change_pe
# Out:
# 2250 249 0

# %% [markdown]
# ## some code to delete specific objects from our database

# %%
# bond_length_predictions[0].index(None)
# for i, j in enumerate(bond_length_predictions[0]):
#     if j == None:
#         print i
        
indices_to_delete = []
for i in bond_length_predictions[0]:
    if 'status' in i:
        indices_to_delete.append(i)
        print i, 'to be deleted'
        bond_length_predictions[0].remove(i)

# for j in bond_length_predictions[0]:
#     if j['_id'] in indices_to_delete

# %%
doc
structure.composition.reduced_formula
# Out:
# u'SbXeF9'

# %%
from bson.objectid import ObjectId

for i in indices_to_delete:
#     result = db.mp_final.delete_one({'_id': ObjectId(i['_id'])})
#     print i['name'], 'deleted', result.deleted_count
# Out:
# Ne deleted 1
# Xe deleted 1
# He deleted 1
# Kr deleted 1
# He deleted 1
# Kr deleted 1
# Xe deleted 1
# He deleted 1
# Kr deleted 1
# P deleted 1
# H2 deleted 1
# EuAg deleted 1
# Xe deleted 1
# He deleted 1
# Kr deleted 1
# Xe deleted 1
# Kr deleted 1

# %% [markdown]
# ## Analysis Functions

# %%
print 'number of unique bonds used to predict volume:', len(bonds)
print 'number of structures predicted:', len(bond_length_predictions[0])

# in iteration 0, we predicted on 67466 compounds. we found 2609 unique bonds used
# Out:
# number of unique bonds used to predict volume: 2609
# number of structures predicted: 67466

# %%
def get_worst_bond_predictions(bonds_dict, iter_index, num_bonds_to_change=10):
    """
    Retrieves a list of the bonds whose estimates were the furthest the median of the
    bond length found in Materials Project
    Args:
        bonds_dict (dict): dictionary containing the full set of bonds
        iter_index (int): index of the iteration
    Returns:
        list containing the worst bond estimates (bond name, previous estimate, new estimate)
    """
#     num_bonds_to_change = 10
    avg_bonds = []
    worst_bonds_predicted = []
    for key in bonds_dict.keys():
        mp_values_median = np.median(np.array(bonds_dict[key]['mp_values']))
        bond_length_estimate = bonds_dict[key]['estimates'][iter_index]
        num_mp_values = len(bonds_dict[key]['mp_values'])
        
        avg_bonds.append([key,
                          bond_length_estimate,
                          mp_values_median,
                          abs(mp_values_median - bond_length_estimate),
                          num_mp_values])
        
    ab = np.array(avg_bonds)
    display_worst_performing_bonds = ab[ab[:,3].astype(float).argsort()][-num_bonds_to_change:]
    worst_bonds_predicted = display_worst_performing_bonds[:,0].tolist()
    
    print display_worst_performing_bonds
    # return something
    return worst_bonds_predicted

# %%
def analyze_bond(bond_to_inspect):
    for b in bond_to_inspect.split('-'):
        e = Element(b)
        print e.symbol, 'atomic radius', e.atomic_radius, 'ionic_radius', e.average_ionic_radius
#     print bonds[bond_to_inspect]
    display(bl_pred_0[bl_pred_0['worst_predicted_bond']==bond_to_inspect])

# %%
def fix_bond_estimates(bonds_dict, worst_bonds_list, iter_index, weight):
    """
    Given a dictionary of bonds and a list of worst performing bonds, change the estimated bond length.
    Initial bond length estimate is r_atomic_e1+r_atomic_e2
    New estimate is adding a weighted difference between the median of bond length in Materials Project
    Args:
        bonds_dict (dict): dictionary containing the full set of bonds
        worst_bonds_list (list): list containing the bonds that we want to change
        iter_index (int): index of the iteration
        weight (float): how much to move the estimate by
    Returns:
        None
    """
    for key in bonds_dict.keys():
        if len(bonds_dict[key]['estimates']) <= iter_index+1:
            # if it's a bond we want to change, update its estimate
            if key in worst_bonds_list:
                mp_values_median = np.median(np.array(bonds_dict[key]['mp_values']))
                prev_bond_length_estimate = bonds_dict[key]['estimates'][-1]

                median_vs_estimate_diff = mp_values_median - prev_bond_length_estimate

                new_bond_length_estimate = prev_bond_length_estimate + weight*median_vs_estimate_diff

                bonds_dict[key]['estimates'].append(new_bond_length_estimate)

                print key, 'changed. Previous estimate:', prev_bond_length_estimate, 'New estimate:', new_bond_length_estimate
                print 'frequency in MP:', len(bonds_dict[key]['mp_values'])
            
            # if this bond does not need to be changed, keep the same estimate
            else:
                bonds_dict[key]['estimates'].append(bonds_dict[key]['estimates'][-1])

# %% [markdown]
# ## Run analysis for initial iteration

# %% [markdown]
# ### create dataFrama object, score the predictions

# %%
cols = ['name', 'worst_predicted_bond', 'expected_distance', 'actual_distance', 'predicted_volume', 'actual_volume',
        'num_atoms', '_id']
bl_pred_0 = pd.DataFrame(bond_length_predictions[0], columns=cols)
bl_pred_0['worst_predicted_bond'].value_counts()

# %%
bl_pred_0['worst_predicted_bond'].value_counts()
# Out:
# O-P      5992
# Li-O     2631
# O-V      1965
# Mn-O     1503
# B-O      1474
# O-Si     1449
# Fe-O     1397
# C-O      1307
# O-Ti     1303
# O-S      1221
# Cr-O     1174
# K-K      1032
# Mo-O      815
# Cs-Cs     809
# Rb-Rb     803
# Co-O      717
# O-W       672
# Nb-O      649
# O-Te      595
# F-Li      555
# Na-Na     529
# Cu-O      526
# H-O       518
# Ca-O      513
# C-N       487
# O-Ta      486
# Ge-O      479
# La-O      457
# Li-Li     444
# O-Se      440
# N-O       434
# Mg-O      430
# Al-O      412
# O-U       393
# Bi-O      381
# O-Sb      379
# As-O      346
# O-Y       341
# Ba-Ba     328
# Ni-O      311
# O-Sr      292
# Fe-Fe     280
# Na-O      244
# O-O       231
# Ag-Ag     228
# Ni-Ni     224
# Cu-S      216
# Ba-O      205
# Sr-Sr     205
# Tl-Tl     191
# Nd-O      190
# Cu-Cu     188
# Ag-O      187
# Ca-Ca     183
# I-O       178
# O-Tl      173
# O-Sm      173
# O-Re      162
# Cl-O      161
# O-Pb      160
# Mo-Mo     159
# Fe-S      156
# O-Sn      154
# O-Zr      149
# Ce-O      145
# Ba-F      144
# Zn-Zn     144
# O-Zn      138
# Co-Co     137
# La-La     136
# Cu-Se     135
# Cd-I      134
# B-B       130
# F-Mn      129
# N-N       128
# O-Sc      124
# Mn-Mn     123
# Hf-O      121
# Ga-O      120
# O-Tm      118
# Sm-Sm     116
# Lu-O      115
# Cr-Cr     114
# Ho-O      114
# F-Na      114
# C-C       112
# S-Zn      112
# Gd-O      111
# O-Pr      110
# N-S       109
# Hg-Hg     108
# Dy-O      107
# Mg-Mg     106
# Ce-Ce     106
# Nb-Nb     104
# Ca-F      104
# Nd-Nd      97
# U-U        92
# Ti-Ti      92
# S-S        91
# F-V        90
# Ga-Ga      88
# P-S        87
# Er-O       84
# Y-Y        83
# Li-S       83
# V-V        83
# Ca-S       82
# Ge-Ni      81
# Pr-Pr      81
# Ag-S       80
# In-In      79
# Eu-O       78
# Be-O       76
# F-Sb       75
# Yb-Yb      73
# Te-Te      72
# Nb-S       72
# Ni-Si      71
# F-Mg       70
# F-Fe       68
# Cr-N       68
# Cd-Cd      67
# Re-Re      66
# Cr-F       66
# O-Tb       66
# N-P        65
# Sc-Sc      65
# Co-Ge      62
# Cr-S       62
# Ho-Ho      61
# Pb-Pb      61
# F-Y        61
# Th-Th      61
# Hg-O       60
# Zr-Zr      60
# Ba-I       60
# S-Ti       60
# Ag-F       59
# Ni-Sn      58
# Ta-Ta      58
# Se-Se      58
# Bi-Bi      56
# S-Sb       56
# Dy-Dy      55
# S-Sn       55
# S-V        55
# Al-Cl      54
# O-Yb       54
# Co-Si      54
# Cu-Te      53
# In-O       53
# Lu-Lu      52
# In-S       52
# Co-S       52
# Er-Er      51
# La-S       50
# Hg-S       50
# S-Ta       50
# F-K        50
# Pu-Pu      50
# Rh-Si      49
# Ni-S       49
# B-N        49
# I-Sr       48
# Gd-Gd      48
# Ge-Rh      47
# Ni-P       47
# I-La       47
# Tb-Tb      47
# Hf-Hf      45
# Tm-Tm      45
# Ge-S       44
# Ru-Si      44
# Ge-Ge      44
# Cl-K       43
# S-Y        42
# Nd-S       42
# Ca-I       42
# Nb-Se      42
# F-Sr       41
# Be-Be      41
# N-W        41
# As-Ni      41
# Ag-Se      40
# Ge-Pt      40
# Pt-Si      40
# Cu-F       39
# Fe-Si      39
# S-Sm       39
# Cl-La      39
# Mn-N       38
# F-Zr       38
# Ni-Sb      38
# Ge-Mn      38
# In-Se      38
# O-Os       38
# Ge-Se      37
# Si-Si      37
# La-Ni      36
# Pm-Pm      36
# O-Ru       36
# Mn-Si      36
# Al-Ni      35
# Ga-S       35
# In-Pd      35
# Co-P       35
# Li-Mg      34
# B-C        34
# I-Pb       34
# Ir-Si      34
# Ag-I       33
# Br-O       33
# Ge-Pd      33
# K-Na       33
# Cd-O       33
# Ac-Ac      33
# Ce-Pd      32
# Np-O       32
# Cl-Nb      31
# F-Pb       31
# In-Ni      31
# Cu-Ge      31
# Se-Ta      31
# W-W        30
# Cl-Fe      30
# Fe-P       30
# F-Ti       30
# Au-In      30
# Cu-Sn      30
# Fe-N       30
# C-Si       30
# Co-Ga      30
# B-Co       30
# Ge-Ir      30
# Cu-I       30
# Pb-S       29
# N-Si       29
# Be-F       29
# Fe-Se      29
# Pd-Yb      29
# F-Sn       29
# In-Rh      29
# Np-Np      29
# S-U        29
# Mn-Sb      29
# Pd-Sb      28
# Cs-K       28
# Al-F       28
# Ni-Zr      28
# Mn-S       28
# Ba-S       28
# Ce-S       28
# Au-Au      28
# Br-Cs      28
# Rh-Sn      28
# Al-Co      28
# Rh-Sc      28
# Co-Sn      28
# Mo-S       28
# Co-N       28
# Os-Si      27
# O-Pt       27
# P-Se       27
# Eu-Eu      27
# Cl-Sb      27
# Au-O       27
# K-O        27
# Fe-Ge      27
# Sn-Sn      27
# Cl-Na      27
# Ag-Te      27
# Na-Rb      27
# Pd-Si      26
# O-Pu       26
# In-Pt      26
# Cu-Si      26
# Er-S       26
# Ge-Ru      26
# Br-Rb      25
# Se-Sm      25
# Al-Au      25
# La-Se      25
# Pd-Sn      25
# Au-Yb      25
# Bi-F       25
# In-Te      25
# N-Zr       24
# As-F       24
# As-Co      24
# B-F        24
# Cl-Te      24
# Nd-Se      24
# Pd-Pd      24
# Cu-Sb      24
# F-Ni       24
# Au-Pm      24
# N-Ti       24
# Mg-Pd      24
# Cl-Cu      24
# Sb-Sb      24
# Nb-Te      24
# Cd-S       24
# Au-F       24
# Cl-Zr      23
# I-I        23
# Cl-Ti      23
# F-Zn       23
# Lu-Pd      23
# Ce-Ni      23
# Al-Fe      23
# O-Tc       23
# Ca-Sb      23
# Li-Tl      23
# Rh-Y       23
# N-V        23
# Hg-Se      23
# La-N       23
# Ba-Cl      23
# Pa-Pa      23
# Dy-S       23
# Ni-Sc      22
# Er-Pd      22
# Ga-Te      22
# Cl-Li      22
# Au-Sm      22
# Ni-Y       22
# Br-La      22
# Cl-Zn      22
# Te-U       22
# Au-Ca      21
# B-S        21
# Hg-Te      21
# N-Ta       21
# Cl-Ga      21
# Pr-S       21
# Br-Y       21
# Ce-Se      21
# Gd-S       21
# Rh-Tm      21
# Cl-Rb      21
# N-Ni       21
# Pd-Sc      21
# Li-Na      21
# Na-Se      21
# I-Y        21
# Se-Sn      21
# As-S       21
# Ga-Ni      21
# Pd-Sm      21
# Hg-I       21
# Cl-In      21
# Ag-Sm      20
# Bi-S       20
# Pd-Y       20
# In-Li      20
# S-W        20
# As-Pd      20
# Co-Zr      20
# Ce-Rh      20
# Ag-Li      20
# Lu-S       20
# Al-S       20
# Pd-Tl      20
# Au-Cl      20
# Ho-Pd      20
# Cl-Sn      20
# Er-Rh      20
# H-N        20
# Pd-S       20
# Er-Ni      20
# Cl-W       20
# Mo-N       20
# Pt-Pt      20
# F-Tl       20
# Ce-Pt      20
# Cl-Ta      20
# Au-Nd      20
# Pr-Se      20
# Se-Ti      20
# Al-Pt      20
# Co-Sb      20
# Sb-Sr      19
# K-Rb       19
# Ce-N       19
# La-Pd      19
# Tc-Tc      19
# Pt-Sc      19
# Bi-Sr      19
# Ho-Rh      19
# Pd-Tm      19
# F-U        19
# Pd-Se      19
# Lu-Rh      19
# Mg-Rh      19
# Cd-P       19
# Ga-Se      19
# Rh-Yb      19
# S-Sc       19
# Au-S       19
# Ho-S       19
# S-Sr       19
# Na-S       19
# Al-Al      18
# Cu-P       18
# K-S        18
# P-Ru       18
# Cu-Y       18
# Se-U       18
# O-Pa       18
# Cl-Y       18
# Au-La      18
# N-U        18
# Ag-Pm      18
# Cd-Sb      18
# S-Tm       18
# Sm-Tl      18
# B-Ir       18
# Au-Ho      18
# Nd-Pd      18
# Rh-Sm      18
# Cl-Mo      18
# Se-V       18
# K-Se       18
# Na-Tl      18
# Au-Ce      18
# Ba-Se      18
# F-Te       18
# Hf-Ni      18
# Ir-Mg      18
# Ta-Te      18
# Cr-Se      18
# Mn-Ti      17
# Cl-Hg      17
# Ni-Pr      17
# Mg-Sm      17
# Mn-Sn      17
# C-Fe       17
# Cu-Sc      17
# Nd-Rh      17
# Ba-Sb      17
# Br-Sn      17
# Ag-Lu      17
# Cl-Co      17
# Cs-F       17
# O-Pd       17
# Au-Pr      17
# Pm-Zn      17
# As-Hg      17
# Ba-Bi      17
# Ge-Zn      17
# Mg-N       17
# Cu-In      17
# Fe-Sb      17
# Br-Hg      17
# As-Cd      17
# Cl-Pb      17
# Ge-Te      17
# Dy-Rh      17
# Au-Sc      17
# F-I        17
# Co-Se      17
# Bi-Te      17
# Ir-Sc      17
# Cl-Cr      17
# Li-Pd      17
# Bi-Se      17
# Hg-Sm      16
# Br-Cu      16
# Li-Sn      16
# Bi-Pd      16
# Ag-Mg      16
# F-P        16
# Hf-Rh      16
# F-Mo       16
# Mg-S       16
# Al-N       16
# I-Zr       16
# Pd-Te      16
# Cl-Cs      16
# Au-Mg      16
# Ru-Sc      16
# La-Rh      16
# Ag-Sc      16
# Li-Pm      16
# In-Ir      16
# Cu-N       16
# Cl-Pd      16
# Fe-Ti      16
# F-La       16
# I-Sn       16
# Pd-Zr      16
# Dy-Pd      16
# Ni-Ti      15
# Ca-Hg      15
# N-Pr       15
# Au-Si      15
# F-Nb       15
# N-Re       15
# F-Nd       15
# Br-K       15
# As-Cu      15
# Mn-P       15
# Pd-Pm      15
# Pr-Tl      15
# Cu-Li      15
# Cl-Sc      15
# Er-Se      15
# Sm-Te      15
# Nd-Ni      15
# Mg-Y       15
# As-Rh      15
# In-Sb      15
# Mn-Te      15
# Lu-Ni      15
# Cd-Se      15
# Hf-Pd      15
# Pt-Yb      15
# Cr-Si      15
# C-Nb       15
# La-Te      15
# Ho-Ni      15
# Ce-Ru      15
# Au-Dy      15
# Cd-Li      15
# Ge-Y       14
# Li-N       14
# Br-In      14
# Mn-Ni      14
# Sm-Zn      14
# Ca-Rh      14
# S-Tl       14
# Rh-Rh      14
# Fe-Zr      14
# Gd-Pd      14
# Li-Rh      14
# Ag-Tl      14
# Co-F       14
# Ag-Tm      14
# Se-Tb      14
# Te-Zr      14
# Ni-Zn      14
# Lu-Ru      14
# Mg-Ni      14
# Al-Br      14
# Au-Sn      14
# Pb-Pd      14
# Cl-P       14
# Ag-La      14
# Nd-Tl      14
# Bi-Ca      14
# Ag-Pb      14
# Br-Cd      14
# Br-Ca      14
# Co-Hf      14
# S-Si       14
# Rh-Tb      14
# C-Co       14
# Al-C       14
# Pd-Pr      14
# Hg-Pm      14
# Co-Sc      14
# Sc-Zn      14
# Pd-Ti      14
# Ni-Te      14
# S-Tb       14
# N-Nb       14
# Ir-Sn      14
# Pr-Zn      14
# Cs-I       14
# Pd-Tb      14
# Y-Zn       14
# F-Rb       14
# Br-Pb      14
# I-In       14
# Pt-Sn      14
# P-Zn       14
# Pr-Pt      13
# Dy-Ni      13
# Pt-Sm      13
# Cr-Te      13
# Ni-Se      13
# Nd-Pt      13
# Ca-Li      13
# Br-Ga      13
# Pm-Rh      13
# Co-In      13
# Lu-Se      13
# Cu-Mg      13
# Ce-Cu      13
# Hg-Yb      13
# Bi-Ni      13
# Ca-Pd      13
# Ag-Pr      13
# Au-Cd      13
# Pb-Rh      13
# Au-Li      13
# Au-Se      13
# Li-Pb      13
# Ag-Y       13
# Rh-Zr      13
# Ca-Pb      13
# As-Mn      13
# Cl-Mn      13
# Ga-Pt      13
# Dy-Se      13
# Li-Sb      13
# Hg-La      13
# Hf-N       13
# I-Te       13
# Se-Y       13
# Tm-Zn      13
# Ca-Cl      13
# S-Yb       13
# Cd-Cl      12
# Mg-Pt      12
# Au-Tm      12
# Au-Te      12
# F-Pt       12
# Cl-Pt      12
# Se-Zr      12
# Sb-Zn      12
# F-Ta       12
# Se-Tl      12
# Ga-Pd      12
# C-S        12
# Li-Se      12
# Sn-Ti      12
# Li-Zn      12
# Pt-Sb      12
# Au-Y       12
# Ag-Yb      12
# As-Sr      12
# As-Zn      12
# Cl-Tl      12
# Ho-Se      12
# Ge-Sm      12
# Cu-Tm      12
# Ir-Ir      12
# Mn-Se      12
# Nd-Te      12
# Co-Mn      12
# N-Th       12
# Ac-Hg      12
# Ba-Ca      12
# Pt-Ti      12
# Cd-Te      12
# N-Nd       12
# As-Ca      12
# Ge-Yb      12
# N-Zn       12
# Ag-Dy      12
# Cs-Rb      12
# Mg-Tm      12
# Cu-La      12
# Sb-Se      12
# Mg-Nd      12
# Co-Ti      12
# Cr-Ge      12
# F-F        12
# Hf-Ir      12
# Ni-Tm      12
# Cl-Sr      12
# Co-U       12
# Cu-Lu      12
# Ca-Tl      12
# Bi-Rh      12
# Ag-Br      12
# Ge-Li      11
# Au-Lu      11
# P-Pd       11
# Ir-O       11
# Ni-Tb      11
# Mg-Pr      11
# F-Ge       11
# C-Ti       11
# N-Se       11
# Hg-Tm      11
# Eu-Pd      11
# Se-Zn      11
# Lu-Zn      11
# Al-Ru      11
# Tl-Y       11
# La-Sb      11
# Ag-Cl      11
# Ac-Au      11
# Ru-Tm      11
# Ru-Y       11
# Mo-Se      11
# Co-Sm      11
# Al-Se      11
# La-Pt      11
# N-Y        11
# Hg-Pr      11
# Ni-Ta      11
# In-Mg      11
# Ca-Pt      11
# Br-U       11
# Ag-Er      11
# P-P        11
# C-Sc       11
# Cl-U       11
# Co-Te      11
# La-Os      11
# Ru-Sb      11
# Nb-Ru      11
# La-Tl      11
# Pa-Tc      11
# Br-Tb      11
# As-Fe      11
# Ag-Ho      11
# F-Pd       11
# Al-Pd      11
# Pr-Te      11
# Au-Eu      11
# In-Sm      11
# Hg-Sb      11
# Rh-Sb      11
# Br-Zn      11
# B-Cl       11
# Br-Fe      11
# Rh-Ti      11
# Sb-Zr      11
# Nb-Ni      10
# Ga-I       10
# Cu-Zr      10
# Au-Br      10
# Ho-Ru      10
# Li-Tm      10
# Br-Br      10
# Sb-Yb      10
# Cl-Er      10
# Ca-Ge      10
# Se-Tm      10
# F-Sm       10
# Cu-Hf      10
# F-Yb       10
# F-Rh       10
# Hg-Li      10
# Bi-Mn      10
# Ir-Li      10
# Ir-Ti      10
# Au-Tb      10
# C-V        10
# Li-Sr      10
# Ce-Te      10
# Cd-Pd      10
# Ga-N       10
# B-Ni       10
# Ge-Nd      10
# O-Rh       10
# Pt-Zr      10
# Er-F       10
# Au-Er      10
# C-La       10
# Ce-Mg      10
# Hg-Y       10
# B-Br       10
# Cr-I       10
# Li-Ni      10
# Sc-Tc      10
# Br-Mn      10
# Cu-Nd      10
# Al-Mo      10
# Al-Mn      10
# La-Li      10
# Pr-Ru      10
# Er-Ru      10
# Hg-Sr      10
# Ge-Tb      10
# Hf-Sb      10
# Hg-Nd      10
# N-Tc       10
# Ac-Li      10
# H-H        10
# Se-Sr      10
# C-Cr       10
# Co-Ho      10
# Gd-Se      10
# O-Th       10
# Ba-Br      10
# Ru-Ta      10
# Ge-Ho      10
# Na-Te      10
# Al-I       10
# Tl-Yb      10
# Ce-Zn      10
# Pd-Sr      10
# Bi-I       10
# Tc-Ti      10
# Au-Pb      10
# Ir-Y       10
# Ba-Cu      10
# Fe-Hf      10
# Ru-Sn      10
# Rh-Zn       9
# In-Sr       9
# Hg-P        9
# Ni-Sm       9
# Ga-Mn       9
# Ga-Rh       9
# Al-Cr       9
# Al-Li       9
# Ag-Tb       9
# Os-Os       9
# F-S         9
# Rh-Te       9
# Te-Zn       9
# Br-Te       9
# Ce-Ir       9
# Sb-Te       9
# Li-Nd       9
# N-Os        9
# Ag-Ca       9
# Dy-Ge       9
# Mg-Tl       9
# K-Te        9
# Nd-Sn       9
# Pt-Tb       9
# Au-Ga       9
# Ir-Sm       9
# Ni-U        9
# Au-Pa       9
# Ag-Nd       9
# Tl-Tm       9
# Se-Yb       9
# I-U         9
# Ru-Ru       9
# In-Tm       9
# Gd-Rh       9
# Cl-I        9
# Co-Nd       9
# Cl-S        9
# C-Mn        9
# Cs-Tl       9
# As-Ba       9
# Dy-Ru       9
# B-Fe        9
# Pt-Sr       9
# Hf-Tc       9
# Co-Pr       9
# Os-Sc       9
# Mn-Rh       9
# Nd-Zn       9
# Al-Ir       9
# Ag-Sn       9
# Ge-Pr       9
# Cu-Dy       9
# Mn-Pd       9
# Cl-Ge       9
# Li-Pt       9
# Er-Li       9
# Fe-Te       9
# Gd-Ni       9
# Ba-Li       9
# Hf-Ru       9
# La-Zn       9
# Te-Ti       9
# Na-Sr       9
# Cl-Mg       9
# Sc-Tl       9
# B-Pd        9
# Cu-Sm       9
# Ho-Li       9
# Bi-Cu       8
# Ru-Th       8
# F-Tb        8
# Ir-Lu       8
# Rh-Th       8
# Hf-Te       8
# Er-Tl       8
# Ga-Li       8
# As-As       8
# Cl-Si       8
# S-Zr        8
# Mg-Ru       8
# Co-Tb       8
# Ho-Sb       8
# Hg-Mg       8
# Ag-Cd       8
# Co-Lu       8
# Fe-Ta       8
# Dy-Sn       8
# I-K         8
# Mg-Sr       8
# Se-Si       8
# Co-Er       8
# Ge-Hf       8
# As-Mg       8
# Mo-P        8
# Ru-Sm       8
# Co-Dy       8
# Ba-Sn       8
# Ag-Ce       8
# Cs-Se       8
# Sb-U        8
# Rb-S        8
# Ca-P        8
# Pb-Se       8
# Co-Fe       8
# Ho-Tl       8
# I-Pt        8
# Te-Y        8
# Pb-Te       8
# Dy-Tl       8
# As-Te       8
# Ca-Sn       8
# Br-Tl       8
# Li-Lu       8
# Hg-Lu       8
# Hf-Pt       8
# Pa-Ru       8
# Pr-Rh       8
# La-Mg       8
# Ge-N        8
# Ga-Sc       8
# Dy-Ir       8
# Br-Ta       8
# Dy-In       8
# Br-Sr       8
# Er-Ge       8
# Ir-Te       8
# Ba-Ge       8
# Li-Sc       8
# Ca-Cd       8
# Cu-Pr       8
# Co-Tm       8
# Pt-Tm       8
# Pt-Te       8
# Er-In       8
# Pd-Pu       8
# Bi-Pt       8
# F-W         8
# Li-Yb       8
# Mn-V        8
# B-Rh        8
# Br-Ti       8
# Hf-S        8
# Sc-Te       8
# Eu-F        8
# Eu-Ni       8
# Ni-Yb       8
# Cd-Y        8
# La-Ru       8
# Ba-P        8
# I-Rb        8
# Ho-Zn       8
# Dy-Hg       8
# Ga-Ir       8
# C-W         7
# Al-Zr       7
# Rh-U        7
# C-Ru        7
# Co-Cr       7
# Ba-Si       7
# P-Rh        7
# I-Ti        7
# Ir-Tm       7
# Ge-I        7
# I-Ta        7
# In-Nd       7
# Au-Sr       7
# Ce-Co       7
# Re-Te       7
# Ca-N        7
# I-Sb        7
# Cu-Ho       7
# Ga-Ru       7
# Au-Zn       7
# Br-Pd       7
# Cl-Lu       7
# C-Pr        7
# Sc-Si       7
# I-Pr        7
# Cu-Ti       7
# Ru-Ti       7
# Pb-Yb       7
# Sc-Se       7
# Re-Ti       7
# Ca-Cu       7
# Br-Ge       7
# Er-Ir       7
# Ho-In       7
# C-Ta        7
# Lu-Mg       7
# As-Ru       7
# Er-Zn       7
# Ni-Th       7
# Rh-Se       7
# Co-Mo       7
# O-Rb        7
# Cd-Sm       7
# Ir-Zn       7
# Os-Tm       7
# Hg-Ho       7
# Ag-Ba       7
# Rb-Te       7
# Zn-Zr       7
# Rb-Se       7
# Cl-Dy       7
# F-Sc        7
# In-Y        7
# Ru-V        7
# Cd-Sc       7
# Co-Th       7
# Co-Ta       7
# Ho-Ir       7
# Ir-La       7
# Ru-Zr       7
# Cl-Se       7
# Pt-Y        7
# Eu-S        7
# Dy-Zn       7
# Ge-Sc       7
# N-Pd        7
# As-Li       7
# Cd-Pm       7
# Pd-Zn       7
# Er-Pt       7
# Br-Sb       7
# Ho-Pt       7
# Co-Nb       7
# Cu-Pd       7
# Ga-Sr       7
# Mg-Pm       7
# Tc-V        7
# Cu-Pb       7
# K-Li        7
# Ce-Hg       7
# Fe-V        7
# Sr-Tl       7
# Se-Te       7
# Ce-Ge       7
# F-Th        7
# Mg-Sn       7
# Sn-Sr       7
# Mg-Se       7
# Al-Ti       7
# Cl-Yb       7
# As-Sn       7
# Al-Te       7
# Au-I        7
# Li-Pr       7
# I-Nb        7
# Ca-In       7
# Au-Th       7
# Sb-Ti       7
# Au-P        7
# Ag-Ge       7
# F-Ru        7
# Cd-Yb       7
# Pm-Tl       7
# Cl-V        7
# Ac-Te       7
# P-Sr        7
# Ge-La       7
# Ce-F        7
# Co-La       7
# Cu-Er       7
# Gd-Ge       7
# Ga-Tm       7
# Hf-Se       7
# F-Ho        7
# Cl-Ru       6
# Ir-Zr       6
# Ba-Na       6
# Mg-Zn       6
# Tc-Th       6
# Pa-Pt       6
# I-Tl        6
# Au-Ba       6
# Cu-Sr       6
# Na-Pd       6
# Ce-Tl       6
# La-P        6
# Au-Mn       6
# Au-Tl       6
# Au-Sb       6
# Rb-Tl       6
# F-Ga        6
# Pd-U        6
# Cs-O        6
# Ti-Zn       6
# Ge-In       6
# Cr-P        6
# Cr-V        6
# Bi-Br       6
# Al-Y        6
# As-Ti       6
# Al-V        6
# C-Mo        6
# B-Tc        6
# Dy-Li       6
# C-Ni        6
# Li-Y        6
# Ga-Y        6
# Li-P        6
# Er-Ga       6
# Re-Si       6
# As-In       6
# Br-Zr       6
# Cl-Hf       6
# Gd-Pt       6
# Cd-Tm       6
# Si-Y        6
# Dy-Mg       6
# Be-N        6
# Br-Li       6
# Hg-Tb       6
# Cl-Re       6
# Ce-Sn       6
# H-S         6
# Dy-Pt       6
# Al-Rh       6
# P-Re        6
# Ag-Sb       6
# Fe-Sc       6
# F-Si        6
# Cd-Ce       6
# Ni-V        6
# Ca-Ni       6
# In-Ti       6
# Fe-Rh       6
# Br-Sm       6
# Pt-U        6
# Cu-Ga       6
# Pt-S        6
# Mn-Ru       6
# Cl-Cl       6
# Al-Cu       6
# Ga-Nd       6
# Ho-Sn       6
# Co-Y        6
# Al-Ge       6
# Co-V        6
# Rh-Tl       6
# Rh-Sr       6
# F-Hf        6
# Br-Sc       6
# Mn-Pt       6
# Cd-Ho       6
# Gd-In       6
# Mg-Na       6
# Ba-Pt       6
# Lu-Pt       6
# Ir-Nd       6
# C-Ce        6
# I-P         6
# Te-Tm       6
# Cd-Na       6
# Cd-Nd       6
# Fe-Sn       6
# Ir-P        6
# Cu-Yb       6
# Dy-Sb       6
# Mg-Sc       6
# Be-Cu       6
# In-La       6
# B-Sc        6
# Cl-Sm       6
# C-Sn        6
# Br-Nb       6
# Fe-Pt       6
# Yb-Zn       6
# Bi-La       6
# Os-Sb       6
# Al-Sr       6
# Sn-Te       6
# Fe-Ni       6
# Ga-Ho       6
# Cd-Pr       6
# In-Lu       6
# In-Yb       6
# Hg-Sc       6
# Dy-Te       6
# Sn-Zn       6
# Pt-Th       6
# P-Sn        6
# Al-Hf       6
# Sc-Sn       6
# I-Si        6
# Hg-Pd       6
# Os-V        6
# C-Cl        6
# Cl-Tb       6
# P-Si        6
# Ho-Os       6
# N-Sc        6
# Ir-Sb       6
# Tc-U        6
# Ca-Te       5
# Cd-Sr       5
# Te-Tl       5
# Hf-Pb       5
# Eu-Tl       5
# Sb-Tm       5
# Sb-Sm       5
# Ge-U        5
# Fe-I        5
# Cl-Gd       5
# Au-Ti       5
# Cr-Nb       5
# Cl-Pu       5
# Cl-Eu       5
# Cr-Ni       5
# Ac-Ag       5
# Cu-Pm       5
# Ag-Gd       5
# Mg-Pb       5
# As-Ge       5
# Be-Pd       5
# Al-Re       5
# As-U        5
# Dy-I        5
# Re-S        5
# As-V        5
# Er-Te       5
# As-La       5
# Lu-Os       5
# Cl-Tm       5
# Bi-In       5
# Ir-Tb       5
# Cu-Pt       5
# Fe-U        5
# Li-Sm       5
# Ge-Mg       5
# Br-Se       5
# Os-Ti       5
# Te-Yb       5
# In-N        5
# Ac-O        5
# Ni-Pa       5
# Bi-Cd       5
# Sb-Y        5
# Cr-Sb       5
# B-Ru        5
# I-Li        5
# Br-Mg       5
# Au-Gd       5
# Ga-Zr       5
# I-Mn        5
# Sn-Tb       5
# Br-Cr       5
# Bi-Yb       5
# La-Pb       5
# Hf-Si       5
# Ba-Te       5
# Pb-Sr       5
# Cl-F        5
# Cu-Zn       5
# Mn-Ta       5
# Sb-V        5
# Ca-Si       5
# Li-Te       5
# B-Os        5
# Bi-Pu       5
# Ni-Pb       5
# In-Pr       5
# Rh-S        5
# Se-Th       5
# Bi-Cl       5
# Al-Ca       5
# Sn-Tm       5
# Fe-Ga       5
# Ge-Lu       5
# Hg-K        5
# Si-Te       5
# Lu-Tc       5
# Nd-Ru       5
# Pt-Zn       5
# Al-Er       5
# Mg-Sb       5
# Mo-Ti       5
# Cd-La       5
# Fe-Tb       5
# Lu-Sb       5
# Bi-Mg       5
# Er-Sb       5
# Mg-P        5
# I-Sm        5
# F-Pr        5
# Pt-Tl       5
# Cu-Gd       5
# Pt-V        5
# Fe-H        5
# Be-Mn       5
# Tb-Te       5
# Ga-Ti       5
# Fe-Mn       5
# Fe-Mo       5
# Tb-Tl       5
# Al-As       5
# As-Zr       5
# As-Cr       5
# Br-Dy       5
# Pt-Ta       5
# Cd-Rh       5
# Mo-Ta       5
# Np-Rh       5
# As-Sm       5
# Ag-In       5
# Ge-Tm       5
# I-Pd        5
# F-Hg        5
# Cd-Lu       5
# Mg-Rb       5
# I-Sc        5
# Ca-Ir       5
# Er-Sn       5
# Be-Pt       5
# Li-Ru       5
# Sb-Tl       5
# As-Nb       5
# Dy-Ga       5
# P-U         5
# Er-I        5
# Fe-Nb       5
# Br-P        5
# Al-Dy       5
# Mo-V        5
# Eu-Hg       5
# Na-Pb       5
# Ru-U        5
# I-Zn        5
# Pt-Pu       5
# C-Zr        5
# Ru-S        5
# Au-Na       5
# Ba-Yb       5
# S-Th        5
# Br-W        5
# Er-Hg       5
# Al-Os       5
# Ir-Sr       5
# S-Te        5
# Ag-Sr       5
# Mo-Ni       5
# Ba-Mg       5
# Lu-Si       4
# N-Sm        4
# Hf-Sn       4
# Ba-Rb       4
# Ac-Tl       4
# Li-Zr       4
# Cl-Ir       4
# Np-Te       4
# Bi-Hf       4
# Ca-Rb       4
# Li-Si       4
# Be-Cl       4
# Si-Sm       4
# Al-Tb       4
# Au-Zr       4
# Gd-Ru       4
# Cs-Na       4
# Ga-Pr       4
# Eu-I        4
# Be-P        4
# Gd-Zn       4
# B-I         4
# Br-Yb       4
# Au-Be       4
# Pu-S        4
# Cu-Tb       4
# Nb-Rh       4
# Gd-Hg       4
# Ag-Zr       4
# Gd-Mg       4
# Au-Pu       4
# F-Os        4
# Br-V        4
# Al-W        4
# Mo-Si       4
# P-Tc        4
# Ni-Pu       4
# Ca-Sr       4
# N-Tb        4
# P-Th        4
# Ga-Yb       4
# P-Ti        4
# Ir-Mn       4
# C-U         4
# I-Nd        4
# Ge-Zr       4
# Ac-Cd       4
# Ho-Mg       4
# As-Np       4
# Si-Tb       4
# Ag-C        4
# As-Mo       4
# Os-Ta       4
# Ho-Mn       4
# Al-B        4
# Ba-Hg       4
# Br-Pt       4
# As-Cl       4
# Os-Te       4
# Hf-Li       4
# Ga-Hf       4
# Pd-Ta       4
# Ce-P        4
# Pr-Sn       4
# Eu-Rh       4
# Ca-Na       4
# Na-Sb       4
# Cd-Cu       4
# Hf-I        4
# As-Se       4
# Sr-Zr       4
# Pd-Th       4
# As-B        4
# Sb-Tb       4
# As-Y        4
# Fe-W        4
# B-Mg        4
# Ba-Ga       4
# Cd-F        4
# Np-Se       4
# I-Se        4
# Mn-Zn       4
# Np-Sb       4
# Hg-Na       4
# Ba-K        4
# Cu-Rh       4
# Cu-Pa       4
# Hg-Rb       4
# Cu-Na       4
# Na-Sn       4
# P-Yb        4
# Np-S        4
# Os-Pa       4
# Ge-Nb       4
# Bi-Ti       4
# Ga-Tb       4
# Ce-Ga       4
# P-Pt        4
# Br-Th       4
# Ce-In       4
# Bi-Sm       4
# Ca-Ga       4
# Cr-Ru       4
# Na-Pt       4
# Ag-Bi       4
# Cl-Ho       4
# F-Gd        4
# Cd-Dy       4
# Pr-Si       4
# Au-Hf       4
# Ce-Li       4
# Nb-Ta       4
# Lu-Tl       4
# Eu-Li       4
# Sb-Th       4
# In-Ru       4
# As-Pt       4
# Ga-Sm       4
# Ga-Sb       4
# Fe-Lu       4
# Ca-Zn       4
# Dy-Si       4
# Sn-Zr       4
# B-Li        4
# As-Si       4
# Si-Tm       4
# Ir-U        4
# Cd-Er       4
# Te-V        4
# Ac-Mg       4
# Gd-Tl       4
# I-Tm        4
# Hf-Zn       4
# Gd-N        4
# I-Th        4
# Pb-Sc       4
# Ba-Pd       4
# Ga-Ge       4
# Hf-Mo       4
# Pu-Rh       4
# Eu-Mg       4
# Bi-Li       4
# Ce-Pb       4
# Al-Pu       4
# N-Yb        4
# Al-Lu       4
# F-Ir        4
# Ga-P        4
# Pm-Sn       4
# Bi-Pr       4
# Ge-Mo       4
# Sb-Sn       4
# Pt-Se       4
# Er-Mg       4
# Ge-P        4
# Pb-Pr       4
# Sm-Y        4
# Bi-Ce       4
# Al-Sc       4
# Nb-Sn       4
# Mo-Zn       4
# Pm-Pt       4
# I-Mg        4
# Rh-Ta       4
# In-P        4
# Be-H        4
# Mo-Te       4
# F-In        4
# Mg-Yb       4
# Ge-Th       4
# Bi-Th       4
# Ga-Mg       3
# Mn-Sr       3
# Bi-Na       3
# Au-Cu       3
# B-Be        3
# Br-H        3
# Si-Ti       3
# Nb-Zn       3
# Ca-Mg       3
# In-Sc       3
# Br-Er       3
# Bi-Tb       3
# Cd-Mg       3
# Cd-Tb       3
# K-Zr        3
# Bi-Nd       3
# P-W         3
# P-V         3
# Ir-Se       3
# Co-Zn       3
# Ag-Eu       3
# As-Ce       3
# Ag-Hg       3
# Bi-U        3
# Ge-Os       3
# Sn-Th       3
# Nd-Pb       3
# Ag-As       3
# Sb-Sc       3
# F-H         3
# I-Ru        3
# F-Np        3
# Bi-Zr       3
# Be-Ni       3
# C-Re        3
# Be-Si       3
# Cr-Ta       3
# Be-Se       3
# Ac-Zn       3
# Cr-Mo       3
# Ir-S        3
# Fe-Ho       3
# Ir-V        3
# Ce-Sb       3
# F-Tm        3
# Ir-N        3
# Ga-Lu       3
# Pa-Te       3
# Hf-Os       3
# Sn-Y        3
# Au-U        3
# As-Ir       3
# Be-Ti       3
# N-Rh        3
# Hg-Zr       3
# Co-I        3
# Co-W        3
# As-Nd       3
# K-Pt        3
# Ba-Ir       3
# Be-Rh       3
# Ag-Zn       3
# As-Pa       3
# C-Ge        3
# Pu-Sb       3
# In-Tb       3
# C-Ga        3
# Mg-Os       3
# Au-N        3
# Au-K        3
# Au-Pd       3
# Gd-Li       3
# Ho-Pr       3
# Si-W        3
# Br-Tc       3
# Ir-Th       3
# Fe-Li       3
# Cr-Fe       3
# Cl-Th       3
# Be-Li       3
# Hg-Pb       3
# Be-Co       3
# In-Na       3
# In-Nb       3
# P-Zr        3
# Cs-Te       3
# Rb-Yb       3
# Na-Y        3
# Na-P        3
# Fe-La       3
# Pu-Te       3
# Mn-Sc       3
# Rb-Sr       3
# Sb-Ta       3
# Ce-Si       3
# Nb-P        3
# Nb-W        3
# Hg-Tl       3
# Ho-Si       3
# Nd-P        3
# Ru-Tb       3
# Ta-Tc       3
# Eu-Si       3
# Sm-Sn       3
# Eu-Pt       3
# Al-Pr       3
# As-Th       3
# Sr-Zn       3
# Sn-Yb       3
# Dy-Y        3
# B-Mn        3
# F-Lu        3
# Au-Np       3
# Cs-Hg       3
# Br-Pr       3
# Br-Re       3
# C-F         3
# Fe-Ru       3
# Br-Lu       3
# Ag-Na       3
# K-Sr        3
# La-Sn       3
# B-Zr        3
# Ga-V        3
# Ga-U        3
# Ga-H        3
# Ge-V        3
# Sn-U        3
# Tc-Zr       3
# Rh-V        3
# B-La        3
# Tc-W        3
# Eu-Sn       3
# Cd-Pb       3
# Re-Se       3
# Ca-Se       3
# Ge-Sr       3
# Pa-Rh       3
# As-Be       3
# O-Pm        3
# Pb-Pt       3
# Bi-Ho       3
# Al-Sm       3
# Na-Ta       3
# Al-Si       3
# Nb-Sb       3
# Eu-Ir       3
# Hf-Mn       3
# Ba-Pb       3
# Br-Np       3
# Pb-Sm       3
# Eu-In       3
# Br-Ni       3
# Ru-Zn       3
# Ti-Tl       3
# B-Ca        3
# B-Cr        3
# Hg-N        3
# Mg-Te       3
# Cs-Li       3
# Eu-Ge       3
# Fe-K        3
# Fe-Y        3
# Cl-Pr       3
# As-Pr       3
# Pr-Sb       3
# Mn-W        3
# Nb-Tc       3
# N-Np        3
# Ce-Y        3
# I-Ni        3
# Ge-Sn       3
# Os-Pr       3
# N-Na        3
# Ce-I        3
# Si-Zn       3
# Ag-K        3
# Ag-N        3
# Ir-Yb       3
# Ta-W        3
# Al-Tc       3
# Ge-Sb       3
# Al-Tm       3
# Ag-Si       3
# Pb-Y        3
# Cl-Rh       3
# Hg-Ni       3
# Br-Si       3
# Mg-Si       3
# Ru-Yb       3
# C-Os        3
# Ba-Cd       3
# Eu-Ga       3
# P-Sm        3
# Cr-U        3
# As-Hf       3
# Gd-Mn       3
# Al-Ho       3
# N-Sn        3
# Si-Zr       3
# Cd-Gd       3
# As-Tm       3
# Gd-Si       3
# Re-Ru       3
# La-Si       3
# B-H         3
# Nd-Sb       3
# Nb-Pt       3
# Cl-H        3
# B-P         3
# B-W         3
# Ga-Pu       3
# As-Ta       3
# Dy-Fe       3
# As-Ga       3
# Ho-Te       3
# Ni-Pm       3
# Hf-Tl       3
# Al-H        3
# Bi-Dy       3
# Al-Np       3
# In-Zn       3
# Pb-Zr       3
# Al-P        3
# Al-Nd       3
# Cs-S        3
# Ba-Y        3
# Gd-Sb       3
# In-Pm       3
# Al-U        3
# Eu-Te       2
# Au-V        2
# Fe-Pa       2
# Nd-Sm       2
# Co-Ni       2
# Nd-Si       2
# Be-Ge       2
# Ac-S        2
# Pu-Si       2
# Cd-Pt       2
# P-Pr        2
# P-Pu        2
# Ge-Si       2
# In-Re       2
# Cl-Tc       2
# I-Na        2
# Nb-Tl       2
# Nb-Ti       2
# H-Si        2
# Ba-Zn       2
# P-Pa        2
# Eu-Zn       2
# Ag-P        2
# Cl-Pa       2
# La-Mn       2
# Np-P        2
# Ga-Th       2
# Er-Pr       2
# Bi-Ir       2
# Ge-Ta       2
# Ir-Pr       2
# Lu-P        2
# Br-Os       2
# Cd-Ge       2
# Ce-Os       2
# In-Pb       2
# Hf-Re       2
# Ag-Th       2
# Co-Pu       2
# Ta-V        2
# Eu-Sb       2
# Ge-Ti       2
# C-Ir        2
# C-In        2
# Cr-Sc       2
# Er-Os       2
# Pa-Pd       2
# H-P         2
# Fe-Tm       2
# Cd-Hg       2
# Pr-Tm       2
# Ir-Np       2
# Hg-Mn       2
# Rb-Sb       2
# Te-Th       2
# Co-Re       2
# Os-Yb       2
# Os-Th       2
# Ga-La       2
# Bi-Tl       2
# Bi-Tm       2
# Dy-Mn       2
# Cr-Pt       2
# Nd-Y        2
# Re-Ta       2
# N-Sr        2
# Pu-Se       2
# Ga-Nb       2
# N-Sb        2
# Al-Ce       2
# Hg-Th       2
# Co-Gd       2
# Br-Tm       2
# C-Lu        2
# Mn-Yb       2
# Fe-Zn       2
# Ta-Ti       2
# B-Re        2
# Ba-Ti       2
# Eu-P        2
# U-W         2
# Ba-Hf       2
# Ba-Tc       2
# Ba-Ni       2
# Os-Sn       2
# Ni-Tl       2
# Nb-Si       2
# Ho-Pb       2
# Pu-Ru       2
# Al-Sb       2
# C-I         2
# B-Pt        2
# Cr-Mn       2
# Ba-Sc       2
# Ho-Nd       2
# Ag-Rb       2
# C-Rh        2
# Ba-Tl       2
# Fe-Pr       2
# Ti-V        2
# Fe-Pd       2
# Ir-Tl       2
# Dy-Sm       2
# Cl-Pm       2
# Mg-Tb       2
# P-Sc        2
# Mo-Re       2
# Li-Os       2
# Mg-Th       2
# Cu-Eu       2
# Gd-Ir       2
# Si-Yb       2
# Er-Fe       2
# Br-Ru       2
# Ir-Ta       2
# I-Rh        2
# Ir-Tc       2
# Cd-Ni       2
# Be-Ir       2
# Au-Bi       2
# Si-Sr       2
# Hf-Sr       2
# B-U         2
# Os-Zr       2
# Gd-Sn       2
# Br-Rh       2
# Os-P        2
# Np-Pt       2
# Pb-U        2
# Ac-In       2
# Re-V        2
# As-W        2
# Re-U        2
# Np-Pd       2
# Br-Cl       2
# Br-Co       2
# I-V         2
# Fe-In       2
# Al-Th       2
# Pa-S        2
# Sm-Tm       2
# C-Y         2
# Bi-Y        2
# Ag-Al       2
# Fe-Ir       2
# Ir-Re       2
# Hg-Rh       2
# Pa-Sb       2
# B-Hf        2
# Ac-Ga       2
# Mn-Nb       2
# Os-Re       2
# Fe-Nd       2
# Ga-Os       2
# Er-Mn       2
# Os-Y        2
# Bi-Lu       2
# N-Pu        2
# N-Pt        2
# I-Mo        2
# Fe-Sm       2
# Be-I        2
# Er-Sm       2
# La-W        2
# Si-Ta       2
# Co-H        2
# Fe-Th       2
# Ir-Pb       2
# Nb-Pd       2
# Gd-P        2
# Co-Li       2
# Lu-Te       2
# Na-Ru       2
# Ca-K        2
# I-Pu        2
# Si-Tc       2
# Na-Ni       2
# As-Tl       2
# C-Tc        2
# Al-La       2
# N-Ru        2
# As-Sc       2
# Ru-Te       2
# Be-Ru       2
# Ho-N        2
# C-Hf        2
# Ho-P        2
# Se-W        2
# Ho-Y        2
# Cs-Sn       2
# P-Tl        2
# In-Sn       2
# P-Tm        2
# K-Tl        2
# Ac-Sr       2
# Gd-I        2
# Br-I        2
# Pm-Y        2
# C-Se        2
# Ag-Au       2
# Ag-Pd       2
# Ga-Gd       2
# Br-S        2
# Si-U        2
# Br-F        2
# B-Se        2
# In-Mn       2
# I-Tb        2
# Al-Ba       2
# Pt-Rh       2
# Au-Ge       2
# Br-Eu       2
# Br-Nd       2
# Br-Pa       2
# Be-Re       2
# Li-W        2
# B-Mo        2
# C-Te        2
# Ac-Rb       2
# Sr-Ti       2
# Dy-P        2
# Cl-Os       2
# Be-Tc       2
# Th-Zn       2
# In-Ta       2
# Cd-N        2
# Cr-Ti       2
# Cr-Cu       2
# Dy-Nd       2
# Ac-Na       2
# Ba-Rh       2
# Re-Sn       2
# Br-Gd       2
# Bi-Os       2
# Be-Zr       2
# Dy-Pb       2
# Ac-Rh       2
# Dy-N        2
# Ga-W        2
# As-Er       2
# Br-Pu       2
# Er-N        2
# Pb-Tm       2
# Cr-Zr       2
# As-Tb       2
# As-Tc       2
# Ar-Ar       2
# I-Yb        2
# C-Cd        2
# Ru-W        2
# Mg-Re       2
# Th-Y        2
# Ce-Cl       2
# Sr-Te       2
# Ba-Be       2
# Tc-Tm       2
# Cu-V        2
# Al-Pa       2
# Ni-Pt       2
# In-Si       2
# Mn-Tc       2
# Br-C        2
# Eu-Pb       2
# Cl-Nd       2
# Dy-Pm       2
# As-Au       2
# Bi-Pa       2
# P-Y         2
# Bi-Er       2
# Pb-Ti       2
# Tb-Zn       2
# Hg-Pt       2
# Fe-Pb       2
# Ca-Re       2
# Ni-Np       2
# Cu-Mn       2
# Ba-Sr       2
# Ca-Hf       2
# Mn-Tb       2
# C-Pt        2
# Bi-N        2
# Pb-Tb       2
# Ag-Cs       2
# Ac-F        2
# Si-V        2
# C-Pd        2
# Pb-Ta       2
# Pb-Th       2
# Nb-Pb       2
# Bi-Co       2
# Cl-Np       2
# Fe-Tc       2
# Cl-Ni       2
# As-I        2
# Bi-Sc       2
# Mo-Pt       2
# Er-Si       2
# Hf-In       1
# Bi-Hg       1
# Mo-Tc       1
# Be-Cd       1
# Ge-Pa       1
# In-Tc       1
# C-Er        1
# Ac-Ge       1
# I-Np        1
# Ce-Fe       1
# Tm-Y        1
# Hg-Sn       1
# Be-Br       1
# Lu-Sm       1
# Hf-Sc       1
# Mg-Nb       1
# Pa-Sm       1
# Cu-Tl       1
# Ag-Mn       1
# Au-Ni       1
# Lu-Na       1
# C-Tl        1
# Bi-Np       1
# As-Na       1
# Cr-Sr       1
# Pa-Se       1
# Ir-Pu       1
# Pa-Si       1
# Ac-Cl       1
# H-I         1
# Ti-Y        1
# Li-Rb       1
# Dy-Sr       1
# Ce-Sc       1
# Lu-Mo       1
# Bi-Eu       1
# Pb-Si       1
# Lu-N        1
# Dy-Pr       1
# As-Os       1
# Ho-Lu       1
# Ir-W        1
# Ga-Zn       1
# Pb-Sb       1
# Mn-Sm       1
# Ac-Dy       1
# Ca-Cs       1
# Be-Te       1
# Cd-Os       1
# Ir-K        1
# Na-Zr       1
# Ba-Th       1
# Cd-Zr       1
# Cd-Zn       1
# Hf-Mg       1
# Lu-Pr       1
# Dy-Pa       1
# Pu-Yb       1
# Ba-Cs       1
# Lu-Mn       1
# Cu-Hg       1
# Ce-Lu       1
# Co-Pt       1
# V-W         1
# Os-Se       1
# Si-Th       1
# Cr-Hg       1
# Cu-W        1
# Cu-Th       1
# Sm-Ta       1
# Br-Mo       1
# I-N         1
# Al-Ta       1
# In-Th       1
# Th-Tm       1
# Re-Sb       1
# N-Te        1
# K-Ru        1
# Pb-Rb       1
# Pb-Re       1
# Bi-K        1
# B-Bi        1
# As-Pu       1
# Mn-Mo       1
# Ag-Ga       1
# Re-Tm       1
# B-Si        1
# B-Sm        1
# Ag-V        1
# P-Ta        1
# N-Tl        1
# Ac-Er       1
# Tl-W        1
# Er-Ho       1
# Mg-Pu       1
# Au-Fe       1
# Ti-W        1
# Ir-Mo       1
# Re-Tc       1
# Ge-Pu       1
# K-Tc        1
# K-Ta        1
# Ac-Al       1
# Ac-N        1
# Ag-Pt       1
# B-Sb        1
# H-Sc        1
# Au-Ta       1
# C-P         1
# Rb-Sn       1
# Ac-I        1
# K-Ti        1
# In-Tl       1
# Ni-W        1
# P-Tb        1
# Al-Tl       1
# Mn-Re       1
# Re-Tb       1
# Be-Sb       1
# Be-Sc       1
# Os-S        1
# Lu-Pb       1
# Ir-Os       1
# Ru-Tc       1
# Sm-Th       1
# Cd-Tl       1
# Er-Yb       1
# Na-Yb       1
# Be-W        1
# Os-W        1
# Ir-Pa       1
# Br-Pm       1
# Pb-Tc       1
# Bi-Ru       1
# Cr-Mg       1
# Nb-Re       1
# Be-Mg       1
# Bi-Zn       1
# Fe-Re       1
# C-Tb        1
# I-Pm        1
# Re-Sm       1
# Nb-Os       1
# S-Se        1
# Mg-Pa       1
# Mo-Sb       1
# Cu-Ir       1
# Ce-Re       1
# C-K         1
# Ag-U        1
# C-Sb        1
# Na-Tm       1
# Na-Tc       1
# K-Y         1
# B-Pr        1
# Hg-Ti       1
# B-Pu        1
# Mg-Np       1
# Nd-Tm       1
# Cs-N        1
# Cs-Mg       1
# Li-Ta       1
# K-Sb        1
# Ga-Mo       1
# As-Sb       1
# Cr-Ho       1
# Br-Ce       1
# Tl-Zn       1
# K-Sn        1
# I-Pa        1
# Tl-Zr       1
# Br-Ir       1
# B-Zn        1
# Cs-Sr       1
# Cs-Si       1
# Sn-V        1
# Sn-W        1
# Al-Zn       1
# K-Si        1
# K-Sc        1
# Er-Np       1
# As-Rb       1
# Mo-Zr       1
# Ce-Dy       1
# Cr-Er       1
# Na-Pr       1
# Bi-Gd       1
# Cd-Sn       1
# Er-Y        1
# Er-P        1
# Cd-Ru       1
# Li-Pu       1
# Sr-W        1
# Cs-H        1
# K-Mo        1
# Hg-Zn       1
# Ho-I        1
# Pt-Re       1
# Cd-Eu       1
# Au-Rb       1
# Hf-K        1
# S-Tc        1
# H-Sr        1
# Ga-Re       1
# C-Pb        1
# As-Eu       1
# Sc-Zr       1
# Be-Sr       1
# As-Re       1
# As-Yb       1
# Hg-Pu       1
# Sc-Sr       1
# Au-Hg       1
# Be-Fe       1
# Pd-Rb       1
# Er-Sr       1
# Cu-Re       1
# Te-W        1
# Sn-Tc       1
# Na-Nd       1
# As-C        1
# I-Tc        1
# Ni-Rh       1
# I-Lu        1
# Ac-Se       1
# Pm-S        1
# Ac-Sn       1
# Si-Sn       1
# C-Gd        1
# La-Nb       1
# Al-Pb       1
# Al-Pm       1
# La-Nd       1
# Os-Ru       1
# Na-Nb       1
# Au-Re       1
# In-Pu       1
# Li-Tb       1
# Mn-Pr       1
# Ho-Re       1
# Mo-Na       1
# Pa-Yb       1
# Nd-Sc       1
# Cs-Ga       1
# Os-Tc       1
# Re-Rh       1
# Mn-Tl       1
# Al-Mg       1
# F-Tc        1
# Ho-Ta       1
# Ru-Se       1
# Al-Nb       1
# Al-Na       1
# Cr-W        1
# H-Re        1
# Hg-In       1
# Sc-V        1
# Li-V        1
# Lu-Th       1
# Mn-Pa       1
# Er-Tb       1
# Er-Ta       1
# Cr-Ir       1
# Er-Pb       1
# Bi-Pm       1
# Np-Tm       1
# Mn-Tm       1
# As-Gd       1
# B-Y         1
# Ga-Pm       1
# In-Zr       1
# Pm-Te       1
# K-P         1
# Cl-N        1
# Sc-W        1
# H-Li        1
# F-N         1
# Cd-V        1
# Re-Sr       1
# La-Np       1
# Gd-Pb       1
# K-La        1
# W-Y         1
# C-Cu        1
# In-Pa       1
# Dy-F        1
# In-Rb       1
# Mn-Zr       1
# Nd-Pa       1
# K-Pr        1
# C-Ca        1
# Hg-Si       1
# Re-Sc       1
# F-O         1
# Sc-Y        1
# Ga-Sn       1
# Hf-Zr       1
# Na-Re       1
# Ho-Tm       1
# Ca-Zr       1
# As-Ho       1
# W-Zr        1
# La-Pm       1
# C-Mg        1
# Sr-Ta       1
# Pb-Zn       1
# Al-Gd       1
# Al-Ga       1
# Pr-W        1
# Ba-Mn       1
# Ba-Mo       1
# As-Dy       1
# Dy-Th       1
# Cr-Pd       1
# In-Np       1
# Cr-Re       1
# Pr-Y        1
# N-Pb        1
# Pm-Si       1
# Ca-Ta       1
# Gd-Te       1
# Pb-V        1
# Fe-Np       1
# K-Nd        1
# Pb-Pm       1
# Pb-Pu       1
# Mg-Mn       1
# Ag-Ru       1
# I-Re        1
# Ge-Rb       1
# Pa-Tl       1
# As-Br       1
# Dy-Na       1
# Pr-Rb       1
# In-U        1
# Re-Y        1
# Re-W        1
# Pb-W        1
# F-Pu        1
# Np-Sn       1
# Np-Si       1
# As-Lu       1
# Mn-Os       1
# Pt-Rb       1
# Ir-Ru       1
# Ga-Si       1
# Bi-Ga       1
# Al-In       1
# Ba-Ta       1
# Ge-Re       1
# K-Nb        1
# Li-Mn       1
# Br-Na       1
# In-V        1
# Be-K        1
# Co-Tc       1
# Nd-Tb       1
# B-Cs        1
# Co-Pa       1
# Nd-Th       1
# Mo-Ru       1
# Mo-Rh       1
# Mg-Ti       1
# Mg-Tc       1
# F-Re        1
# Li-Ti       1
# Li-Th       1
# Li-Tc       1
# In-W        1
# Mo-Tl       1
# Ho-Na       1
# B-Ti        1
# Na-Si       1
# Al-Sn       1
# U-Zn        1
# Ta-Tm       1
# Pm-Tm       1
# Hf-P        1
# Os-Sm       1
# Ag-Hf       1
# Ba-Ho       1
# Nb-Sr       1
# B-Sn        1
# Pu-Tm       1
# Be-S        1
# B-Ta        1
# In-K        1
# La-Re       1
# B-Np        1
# Ho-Pm       1
# Lu-Y        1
# Br-Hf       1
# Rh-Tc       1
# Ir-Nb       1
# Sb-Tc       1
# Pm-Pu       1
# Ag-Be       1
# Mn-Nd       1
# Mn-Np       1
# Ho-Sm       1
# Ni-Sr       1
# F-Pa        1
# F-Pm        1
# Ga-Tc       1
# Ga-Np       1
# Cr-Rh       1
# Lu-U        1
# H-Pt        1
# B-Nd        1
# Ge-W        1
# Bi-Sb       1
# U-Yb        1
# Rh-W        1
# Ga-Pa       1
# Pa-U        1
# Pa-Y        1
# K-N         1
# Ba-Os       1
# Ac-La       1
# Er-Na       1
# Ac-Si       1
# K-Ni        1
# Ge-Tc       1
# Ag-Ti       1
# La-Tc       1
# Pu-Zn       1
# Np-Tl       1
# K-V         1
# Na-Os       1
# Hf-Hg       1
# Os-Pt       1
# Er-Gd       1
# Er-La       1
# K-Os        1
# La-Tb       1
# Be-Hf       1
# Be-Hg       1
# Pa-Zn       1
# F-Se        1
# Ba-H        1
# As-H        1
# Ag-Cr       1
# B-Na        1
# As-K        1
# Br-Ho       1
# Ce-Mn       1
# Mn-Y        1
# P-Pb        1
# Bi-Tc       1
# Ge-Np       1
# Ac-Br       1
# Ge-Na       1
# Eu-Se       1
# Ga-Ta       1
# Ba-In       1
# Bi-Mo       1
# Np-Tc       1
# Al-Yb       1
# Fe-Mg       1
# Gd-Sm       1
# Pr-Sc       1
# Pu-Sn       1
# Eu-Na       1
# Name: worst_predicted_bond, dtype: int64

# %%
bl_pred_0['score'] = bl_pred_0.apply(score, args=('predicted_volume','actual_volume','num_atoms'), axis=1)

# %%
display(bl_pred_0.head())
print bl_pred_0['score'].mean()
# Out:
#           name worst_predicted_bond  expected_distance  actual_distance  \
# 0        Ni3O4                 Ni-O           1.961357         1.880527
# 1  Li2Fe2Si2O7                 Li-O           2.082160         1.917591
# 2         YbZn                Yb-Zn           2.818840         3.127887
# 3      La2SiO5                 O-Si           1.730899         1.620021
# 4        HfCr2                Cr-Cr           2.753161         2.493218
#
#    predicted_volume  actual_volume  num_atoms                       _id  \
# 0         81.539999      71.868570        7.0  58a781ba7f079f2fd3b86cfe
# 1        259.914669     203.027985       13.0  58a781bb7f079f2fd3b86cff
# 2         34.484139      47.115209        2.0  58a781bc7f079f2fd3b86d00
# 3        584.638030     479.329349       32.0  58a781bc7f079f2fd3b86d01
# 4        240.716605     178.768942       12.0  58a781bd7f079f2fd3b86d02
#
#       score
# 0  0.976962
# 1  3.094228
# 2  4.465758
# 3  2.327015
# 4  3.650301
# 2.86690634626

# %% [markdown]
# ### Create a bonds dictionary

# %%
# create_bonds_dict()
# len(bonds)
# bl_pred_0.apply(get_mp_values,axis=1)
# update_estimates(0)

bond_to_inspect = 'Ar-Ar'
display(bl_pred_dfs[0][bl_pred_dfs[0]['worst_predicted_bond']==bond_to_inspect])
display(bl_pred_dfs[1][bl_pred_dfs[0]['worst_predicted_bond']==bond_to_inspect])
pprint.pprint(bonds[bond_to_inspect])
# Out:
#       name worst_predicted_bond  expected_distance  actual_distance  \
# 1771    Ar                Ar-Ar               1.42         3.988628
# 11783   Ar                Ar-Ar               1.42         3.987594
#
#        predicted_volume  actual_volume  num_atoms                       _id  \
# 1771           2.024650      44.869952        1.0  58a783987f079f2fd3b873eb
# 11783          4.065892      90.037547        2.0  58a78cee7f079f2fd3b89b0d
#
#            score
# 1771   30.296203
# 11783  30.395570
#       name worst_predicted_bond  expected_distance  actual_distance  \
# 1771    Ar                Ar-Ar               1.42         3.988628
# 11783   Ar                Ar-Ar               1.42         3.987594
#
#        predicted_volume  actual_volume  num_atoms                       _id  \
# 1771           2.024650      44.869952        1.0  58a783987f079f2fd3b873eb
# 11783          4.065892      90.037547        2.0  58a78cee7f079f2fd3b89b0d
#
#            score
# 1771   30.296203
# 11783  30.395570
# {'estimates': [1.4199999999999999, 2.7040555086763436, 3.3460832630145152],
#  'mp_values': [3.988628004705375, 3.98759403]}

# %%
df = bl_pred_0[bl_pred_0['worst_predicted_bond']=='I-P']
df['expected_distance'].tolist()
# Out:
# [2.364791737209144,
#  2.361670098414481,
#  2.3633727125266653,
#  2.36458204490361,
#  2.3633727125266653,
#  2.36458204490361]

# %%
# bl_pred_dfs[1].head()
# len(bond_length_predictions[1])
# bl_pred_dfs[0]['score'] == bl_pred_dfs[1]['score']
len(bond_length_predictions)
# bond_length_predictions = bond_length_predictions[0:1]
bl_pred_dfs = bl_pred_dfs[0:1]
scores = scores[0:1]
bonds_updated_this_iter = bonds_updated_this_iter[0:1]

# %% [markdown]
# ### Fix the bonds baseed on median

# %%
print '[name, estimate, median (in MP), difference, freq in MP]'
# bonds_list_to_change_0 = get_worst_bond_predictions(bonds, 0)
# Out:
# [name, estimate, median (in MP), difference, freq in MP]
# [[u'Cs-K' u'4.8 ang' u'3.97073516816' u'0.829264831842' u'32']
#  [u'K-Ta' u'3.65 ang' u'2.80447186293' u'0.845528137065' u'1']
#  [u'K-Mo' u'3.65 ang' u'2.78237719929' u'0.867622800705' u'1']
#  [u'Ir-K' u'3.55 ang' u'2.66783199419' u'0.882168005807' u'1']
#  [u'Cs-Cs' u'5.2 ang' u'4.29233469875' u'0.907665301252' u'949']
#  [u'Cs-Na' u'4.4 ang' u'3.4780854159' u'0.921914584101' u'10']
#  [u'K-Zr' u'3.75 ang' u'2.82134257631' u'0.928657423689' u'3']
#  [u'Hf-K' u'3.75 ang' u'2.81135453055' u'0.938645469451' u'1']
#  [u'F-F' u'1.0 ang' u'2.4894341553' u'1.4894341553' u'12']
#  [u'Ar-Ar' u'1.42 ang' u'3.98811101735' u'2.56811101735' u'2']]

# %%
e = Element('Sm')
print e.symbol, e.atomic_radius, e.average_ionic_radius
analyze_bond('F-F')
# Out:
# Sm 1.85 ang 1.229 ang
# F atomic radius 0.5 ang ionic_radius 0.705 ang
# F atomic radius 0.5 ang ionic_radius 0.705 ang
#        name worst_predicted_bond  expected_distance  actual_distance  \
# 11424  KrF2                  F-F                1.0         2.795223
# 13895  KrF2                  F-F                1.0         2.818688
# 14070    F2                  F-F                1.0         1.427373
# 14572  XeF2                  F-F                1.0         3.067668
# 16495    F2                  F-F                1.0         1.426752
# 28509  XeF6                  F-F                1.0         2.535056
# 33189  XeF6                  F-F                1.0         2.443812
# 48741  XeF3                  F-F                1.0         2.877965
# 51434    F2                  F-F                1.0         1.426354
# 52290    F2                  F-F                1.0         2.231050
# 54886    F2                  F-F                1.0         1.426771
# 67389  XeF6                  F-F                1.0         2.550776
#
#        predicted_volume  num_atoms                       _id
# 11424          2.933135        3.0  58a78cb57f079f2fd3b899a6
# 13895          6.034980        6.0  58a78e227f079f2fd3b8a350
# 14070         22.006291        4.0  58a78e3b7f079f2fd3b8a3ff
# 14572          2.515601        3.0  58a78e8a7f079f2fd3b8a5f5
# 16495         26.271550        4.0  58a78fb87f079f2fd3b8ad78
# 28509        115.301076      112.0  58a797b67f079f2fd3b8dc67
# 33189        135.696252      112.0  58a79ad27f079f2fd3b8eeb0
# 48741         14.110571       16.0  58a7a4a77f079f2fd3b92b74
# 51434         32.541423        4.0  58a7a63e7f079f2fd3b935f9
# 52290          8.000000        8.0  58a7a6bb7f079f2fd3b93951
# 54886         21.919076        4.0  58a7a8477f079f2fd3b94375
# 67389        116.034303      112.0  58a7afcd7f079f2fd3b9744f

# %%
fix_bond_estimates(bonds, bonds_list_to_change_0, 1.0)
# fixed these 10 bonds!
# Out:
# K-Zr changed. Previous estimate: 3.75 ang New estimate: 2.82134257631
# K-Ta changed. Previous estimate: 3.65 ang New estimate: 2.80447186293
# Ir-K changed. Previous estimate: 3.55 ang New estimate: 2.66783199419
# Cs-Cs changed. Previous estimate: 5.2 ang New estimate: 4.29233469875
# F-F changed. Previous estimate: 1.0 ang New estimate: 2.4894341553
# Ar-Ar changed. Previous estimate: 1.42 ang New estimate: 3.98811101735
# K-Mo changed. Previous estimate: 3.65 ang New estimate: 2.78237719929
# Hf-K changed. Previous estimate: 3.75 ang New estimate: 2.81135453055
# Cs-Na changed. Previous estimate: 4.4 ang New estimate: 3.4780854159
# Cs-K changed. Previous estimate: 4.8 ang New estimate: 3.97073516816

# %%
bonds['K-Zr']
# Out:
# {'estimates': [3.75, 2.8213425763106366],
#  'mp_values': [3.1258710635627232, 2.6362394492076864, 2.8213425763106366]}

# %%
for b in bonds_list_to_change_0:
    analyze_bond(b)
# Out:
# {'estimates': [4.800000000000001, 3.9707351681583622], 'mp_values': [4.0060860595722891, 4.0733989799999994, 3.8854681026626752, 4.2174241468943876, 3.4887997033647276, 3.507288149327807, 3.7920796517142858, 3.5133968693683966, 4.2119310923908291, 3.6486326412019006, 3.2259987157600718, 3.8387646345688387, 3.7926367591751529, 3.9914597714269573, 3.9947854646414789, 3.9490350101165119, 3.9930559519758604, 3.9762693531885849, 3.7590593757785005, 3.987167418979126, 3.9375295857046937, 3.913329450928845, 3.9968981228822145, 4.0766969400000077, 4.0767141814463965, 4.1426638431417162, 3.2323603137520758, 3.8620127052675932, 3.9652009831281392, 4.093135434607091, 4.0576823631847043, 4.1604729855405491]}
#                     name worst_predicted_bond  expected_distance  \
# 416             Cs2KTiF6                 Cs-K                4.8
# 3886            Cs2KAgF6                 Cs-K                4.8
# 4232             Cs2KNF6                 Cs-K                4.8
# 4834            Cs2KBiF6                 Cs-K                4.8
# 4904           Cs2K2TeO5                 Cs-K                4.8
# 5274            CsK2AuO2                 Cs-K                4.8
# 5535        CsK2Sc(PO4)2                 Cs-K                4.8
# 6046          Cs2K2Cd3O5                 Cs-K                4.8
# 7089            Cs2KPbF6                 Cs-K                4.8
# 7275            CsK2CoO2                 Cs-K                4.8
# 9234   CsKNa2Li12(SiO4)4                 Cs-K                4.8
# 10661       CsK2Ho(PO4)2                 Cs-K                4.8
# 10753             CsK2Sb                 Cs-K                4.8
# 11126           Cs2KMnF6                 Cs-K                4.8
# 11139           Cs2KMnF6                 Cs-K                4.8
# 13384           Cs2KCuF6                 Cs-K                4.8
# 14446            Cs2KVF6                 Cs-K                4.8
# 19681           Cs2KCrF6                 Cs-K                4.8
# 21121           CsK4TlO4                 Cs-K                4.8
# 23094           Cs2KFeF6                 Cs-K                4.8
# 24185           Cs2KNiF6                 Cs-K                4.8
# 24196           Cs2KCoF6                 Cs-K                4.8
# 27956           Cs2KRhF6                 Cs-K                4.8
# 27975           Cs2KMoF6                 Cs-K                4.8
# 31685          Cs2KZrOF5                 Cs-K                4.8
# 32924           Cs2KTlF6                 Cs-K                4.8
# 33212   CsKNaLi13(SiO4)4                 Cs-K                4.8
# 58238             CsK2Bi                 Cs-K                4.8
# 66491           Cs2KGaF6                 Cs-K                4.8
# 66594           Cs2KInF6                 Cs-K                4.8
# 66797       YbCsK2(PO4)2                 Cs-K                4.8
# 67333            Cs2KYF6                 Cs-K                4.8
#
#        actual_distance  predicted_volume  num_atoms                       _id
# 416           4.006086        340.535045       10.0  58a7826c7f079f2fd3b86ea0
# 3886          4.073399        340.535046       10.0  58a7860c7f079f2fd3b87c2f
# 4232          3.885468        340.535045       10.0  58a786c47f079f2fd3b87d89
# 4834          4.217424        340.535078       10.0  58a788b47f079f2fd3b87fe3
# 4904          3.488800       2216.674767       40.0  58a788c07f079f2fd3b88029
# 5274          3.507288       1547.246516       24.0  58a788f87f079f2fd3b8819b
# 5535          3.792080        435.891541       14.0  58a789227f079f2fd3b882a0
# 6046          3.513397       1322.085341       24.0  58a789707f079f2fd3b884a0
# 7089          4.211931        340.535045       10.0  58a78a117f079f2fd3b888b3
# 7275          3.648633        322.949037        6.0  58a78a2c7f079f2fd3b8896d
# 9234          3.225999       1326.257127       36.0  58a78b527f079f2fd3b89114
# 10661         3.838765        448.111050       14.0  58a78c417f079f2fd3b896ab
# 10753         3.792637        340.535118        4.0  58a78c4f7f079f2fd3b89707
# 11126         3.991460        340.535119       10.0  58a78c8a7f079f2fd3b8987c
# 11139         3.994785        340.059095       10.0  58a78c8b7f079f2fd3b89889
# 13384         3.949035        340.535046       10.0  58a78dd97f079f2fd3b8a151
# 14446         3.993056        341.421027       10.0  58a78e757f079f2fd3b8a577
# 19681         3.976269        340.535103       10.0  58a791af7f079f2fd3b8b9ea
# 21121         3.759059       3860.170930       80.0  58a792a57f079f2fd3b8bf8a
# 23094         3.987167        340.535046       10.0  58a794157f079f2fd3b8c73f
# 24185         3.937530        340.535122       10.0  58a794dd7f079f2fd3b8cb82
# 24196         3.913329        340.535086       10.0  58a794df7f079f2fd3b8cb8d
# 27956         3.996898        340.535140       10.0  58a797597f079f2fd3b8da3e
# 27975         4.076697        340.535083       10.0  58a7975d7f079f2fd3b8da51
# 31685         4.076714        346.851699       10.0  58a799e47f079f2fd3b8e8d0
# 32924         4.142664        340.535045       10.0  58a79aa87f079f2fd3b8eda7
# 33212         3.232360       2707.434308       72.0  58a79ad57f079f2fd3b8eec7
# 58238         3.862013        340.535045        4.0  58a7aa2c7f079f2fd3b9508d
# 66491         3.965201        340.535045       10.0  58a7af397f079f2fd3b970cd
# 66594         4.093135        340.535045       10.0  58a7af4b7f079f2fd3b97134
# 66797         4.057682        380.173166       14.0  58a7af6e7f079f2fd3b971ff
# 67333         4.160473        340.535046       10.0  58a7afc37f079f2fd3b97417
# {'estimates': [3.6500000000000004, 2.8044718629345606], 'mp_values': [2.8044718629345606]}
#         name worst_predicted_bond  expected_distance  actual_distance  \
# 36955  KTaPt                 K-Ta               3.65         2.804472
#
#        predicted_volume  num_atoms                       _id
# 36955        149.732713        3.0  58a79d127f079f2fd3b8fd68
# {'estimates': [3.6500000000000004, 2.7823771992949213], 'mp_values': [2.7823771992949213]}
#          name worst_predicted_bond  expected_distance  actual_distance  \
# 37004  KMoRu2                 K-Mo               3.65         2.782377
#
#        predicted_volume  num_atoms                       _id
# 37004        149.732713        4.0  58a79d197f079f2fd3b8fd9a
# {'estimates': [3.5500000000000003, 2.667831994192957], 'mp_values': [2.6678319941929569]}
#         name worst_predicted_bond  expected_distance  actual_distance  \
# 36956  KBIr2                 Ir-K               3.55         2.667832
#
#        predicted_volume  num_atoms                       _id
# 36956        137.760008        4.0  58a79d127f079f2fd3b8fd69
# {'estimates': [5.2, 4.292334698748215], 'mp_values': [4.3681630233027704, 5.2684252218804755, 4.0306191821977659, 4.1689329454589252, 4.5212977701928549, 4.4907040534736016, 4.3525417060582221, 5.1444081194336464, 5.209288413309447, 4.4574234567414424, 4.10694538, 3.868386689372147, 5.4027922999999998, 4.5230806264491399, 4.3810608200000001, 4.3336577542018508, 4.30828363, 4.8787137500000002, 4.3775288405855681, 4.2084409725714025, 5.0457946436555501, 3.813594042075052, 5.0205493627617432, 4.067269972102971, 4.1063385535298256, 4.1917402403909172, 4.0668137535714157, 3.890137699806119, 4.1497268885946612, 4.029138726162631, 4.2941247583377944, 4.3240096860368631, 4.5024703669534576, 4.3010350857079072, 4.1292052065523253, 4.183623627432608, 4.2919948700026112, 4.1210710500000003, 3.9912306062981138, 3.8622674599945594, 3.9829091063289361, 4.22603872, 4.9843506169709126, 4.8303920517563661, 4.4990470190152179, 4.3163184699999997, 4.8417994223167664, 3.9270312799999996, 4.1183301099999996, 4.101337559572352, 4.4913718899657118, 4.1983112249295438, 3.9472748809843989, 4.6558627599999998, 4.0568876161251968, 4.0503898500000002, 4.0568366105087907, 4.6917322890238706, 4.5581822340260043, 4.2163602399742599, 4.2883728999999997, 4.0000907799999998, 4.1370776600000001, 3.7664062742775832, 4.0649006999999999, 3.8769490667393884, 4.6770058266822243, 3.9332488549069691, 4.7581726983579715, 4.5660063756380493, 4.4160967523692385, 4.6830994351368558, 4.1571856445547928, 4.2622919699999997, 4.6573862928970202, 3.7910845445505594, 5.2052888173436704, 4.4616521122425477, 4.4625962799999996, 4.9024845199999998, 5.2682663145250892, 4.2483548568144869, 3.8061359676334345, 4.2726996495066869, 4.2593665929268907, 4.4578027034752115, 3.4920979042169056, 3.5254231409756547, 4.1369166319836106, 4.9081170899999993, 4.2229736025612636, 4.2136785969018344, 4.3611878107706694, 3.5112134409691591, 3.8963063765601746, 4.3953872837205941, 4.2977179123697669, 4.6453903677073836, 4.6726364947740722, 4.2175009580362444, 4.0825449100000002, 4.3668039554052465, 4.2523073800000004, 4.5629995900000004, 4.1943151664381269, 4.5748950926349723, 5.2519964388625411, 4.4527659407637445, 5.170327295447394, 3.7021366200000001, 4.5481328409719106, 4.3473172114124443, 4.3672642682443481, 4.3955487154662931, 4.9765378800000004, 4.5303529362189359, 4.9830498547756292, 3.7647737718676417, 4.5254220608834563, 5.5182736772246299, 3.7710183399999999, 4.4724088899999987, 4.2408780162790611, 4.522930811207595, 3.9991552399999999, 4.0425768910820317, 4.1596880757670434, 4.2729749999999989, 4.3511810000000004, 5.1590137634734115, 4.560954403369089, 4.6125086068767187, 4.4976013437924589, 4.0149651468260705, 4.22889014228861, 3.8413103392334698, 4.1909622690371044, 4.4476154067947329, 3.9685935672420802, 4.0408042296181996, 3.7847618480559362, 4.5471449296434949, 4.2373841670559909, 3.7804185689233067, 3.7966733504579309, 4.3018238045164496, 3.7418205890681882, 4.5274207200000003, 4.0012628025066341, 4.7775552283872145, 4.8322901900000002, 3.5463646433753944, 4.0573211479441209, 4.1985499673479447, 4.3027084722584608, 4.5000339929661459, 4.3064863500000001, 3.8521929877496932, 3.9491088254410567, 4.3443713400000004, 4.1905604214097405, 3.8980670218294313, 4.2751508210932112, 4.4324199787337708, 4.1824639973807338, 4.5454546300000001, 4.4358122326403642, 4.5201680750576889, 3.7131732585004498, 4.6752155399999999, 3.6088390154207652, 4.2876421442801123, 4.0683874931211967, 4.0828674243919973, 4.283057359999999, 4.0548402967557475, 4.1077223176230415, 4.2791351338715309, 4.3431968022277774, 4.2550874231720091, 4.6553056816412992, 4.7928401665472791, 3.7983092654114574, 4.7461820234429251, 3.8375095193134525, 4.1143805438483927, 4.0523093516704698, 4.4822429927268539, 3.9942099127947732, 4.1035496900000004, 4.231349176075434, 4.195505240735355, 4.0754188303117944, 3.9677872299999999, 4.3998195729041205, 4.3362458645576698, 3.9520937300000001, 4.2989158543246067, 4.4299495356267427, 3.9213 ...
#                   name worst_predicted_bond  expected_distance  \
# 10            CsAg3Se2                Cs-Cs                5.2
# 87             CsCrCl3                Cs-Cs                5.2
# 99              CsTiF4                Cs-Cs                5.2
# 118       Cs2PtC2(OF)4                Cs-Cs                5.2
# 184          CsSi2SbO7                Cs-Cs                5.2
# 401          Cs2NaScF6                Cs-Cs                5.2
# 421          Cs2NaGaF6                Cs-Cs                5.2
# 448                 Cs                Cs-Cs                5.2
# 466            CsAuCl3                Cs-Cs                5.2
# 477           CsPH3O3F                Cs-Cs                5.2
# 501           CsCu4Se3                Cs-Cs                5.2
# 506            Cs2LiF3                Cs-Cs                5.2
# 528            CsHgCl3                Cs-Cs                5.2
# 553       Cs2Pd(ICl2)2                Cs-Cs                5.2
# 601               CsAu                Cs-Cs                5.2
# 607          Cs2AgSbS4                Cs-Cs                5.2
# 787           CsYHgSe3                Cs-Cs                5.2
# 837             CsPbI3                Cs-Cs                5.2
# 838              CsNO3                Cs-Cs                5.2
# 864          Cs3CuTeS9                Cs-Cs                5.2
# 1066       Cs3B12H12Br                Cs-Cs                5.2
# 1072              Cs3O                Cs-Cs                5.2
# 1075       Cs3B12H12Cl                Cs-Cs                5.2
# 1138      Cs2Ti(AgS2)2                Cs-Cs                5.2
# 1148              CsN3                Cs-Cs                5.2
# 1246      Cs2Ba2(CO3)3                Cs-Cs                5.2
# 1253         Cs(AsRh)2                Cs-Cs                5.2
# 1287      Cs2Zr(SiO3)3                Cs-Cs                5.2
# 1294           Cs2AgF4                Cs-Cs                5.2
# 1365            CsInS2                Cs-Cs                5.2
# 1478           Cs3PSe4                Cs-Cs                5.2
# 1525          CsCrP2O7                Cs-Cs                5.2
# 1772      Cs2Pd(IBr2)2                Cs-Cs                5.2
# 1917          CsNaSnF6                Cs-Cs                5.2
# 1975             Cs3Bi                Cs-Cs                5.2
# 2027            CsMgH3                Cs-Cs                5.2
# 2079            CsMgO3                Cs-Cs                5.2
# 2103           CsBi3S5                Cs-Cs                5.2
# 2119            Cs2VF6                Cs-Cs                5.2
# 2159         CsNb2BiO7                Cs-Cs                5.2
# 2165            CsFeF4                Cs-Cs                5.2
# 2303        Cs2Bi8Se13                Cs-Cs                5.2
# 2387          Cs2ZnCl4                Cs-Cs                5.2
# 2471       CsKTeH6SO10                Cs-Cs                5.2
# 2498           CsAsOF4                Cs-Cs                5.2
# 2571            CsFeF3                Cs-Cs                5.2
# 2583            Cs2WS4                Cs-Cs                5.2
# 2619          CsTmCoS3                Cs-Cs                5.2
# 2648       CsEr2Cu3Se5                Cs-Cs                5.2
# 2701          Cs2UMoO7                Cs-Cs                5.2
# 2703    CsLiH4S2(NO3)2                Cs-Cs                5.2
# 2887          CsB2H5O6                Cs-Cs                5.2
# 2919          Cs2LiCl3                Cs-Cs                5.2
# 2923           CsLi2I3                Cs-Cs                5.2
# 2924          Cs3LiCl4                Cs-Cs                5.2
# 2929          Cs2Li3F5                Cs-Cs                5.2
# 2932           CsLi2F3                Cs-Cs                5.2
# 2934          CsLi2Br3                Cs-Cs                5.2
# 2937          CsLi2Cl3                Cs-Cs                5.2
# 2938         Cs3Li2Cl5                Cs-Cs                5.2
# 2962          CsUAgSe3                Cs-Cs                5.2
# 2970           CsUCuS3                Cs-Cs                5.2
# 2975           CsUAgS3                Cs-Cs                5.2
# 3063             CsRbO                Cs-Cs                5.2
# 3162          CsCeCuS3                Cs-Cs                5.2
# 3242         Cs4Sn2Au7                Cs-Cs                5.2
# 3277            CsNaTe                Cs-Cs                5.2
# 3297         Cs2LiMnO4                Cs-Cs                5.2
# 3422          YbCsP2O7                Cs-Cs                5.2
# 3462      Cs2Pd(IBr2)2                Cs-Cs                5.2
# 3539          Cs3ZnCl5                Cs-Cs                5.2
# 3583         Cs2NbAgS4                Cs-Cs                5.2
# 3600     CsSc3(CuTe3)2                Cs-Cs                5.2
# 3610          Cs2Hg6S7                Cs-Cs                5.2
# 3745           CsMgPO4                Cs-Cs                5.2
# 3751       Cs3Mn3V4O16                Cs-Cs                5.2
# 3823      CsRb(MnCl3)2                Cs-Cs                5.2
# 3891              CsO2                Cs-Cs                5.2
# 3940          Cs(MoS)3                Cs-Cs                5.2
# 3949            CsPbF3                Cs-Cs                5.2
# 4092           CsCrCl3                Cs-Cs                5.2
# 4111   Cs3Mg3In(PO3)12                Cs-Cs                5.2
# 4137            Cs3ClO                Cs-Cs                5.2
# 4155            CsSnO3                Cs-Cs                5.2
# 4176           Cs2PtF6                Cs-Cs                5.2
# 4218            CsCuF4                Cs-Cs                5.2
# 4311       Cs2Si(HO2)2                Cs-Cs                5.2
# 4382           CsCr5S8                Cs-Cs                5.2
# 4455         Cs4Mg3F10                Cs-Cs                5.2
# 4566            CsAsF4                Cs-Cs                5.2
# 4581         Cs2Ni3Se4                Cs-Cs                5.2
# 4590         Cs2Pt3Se4                Cs-Cs                5.2
# 4592         Cs2Pd3Se4                Cs-Cs                5.2
# 4593        Cs2Li2SiO4                Cs-Cs                5.2
# 4607         Cs2NaAsO4                Cs-Cs                5.2
# 4626         Cs2NaTiF6                Cs-Cs                5.2
# 4686           Cs2MgH4                Cs-Cs                5.2
# 4715       Cs3Sm(PS4)2                Cs-Cs                5.2
# 4830         Cs2NaBiF6                Cs-Cs                5.2
# 4857             CsCuO                Cs-Cs                5.2
# 4887         YbCsCoSe3                Cs-Cs                5.2
# 4912            CsNaSe                Cs-Cs                5.2
# 4913            CsMgF3                Cs-Cs                5.2
# 4929            CsCdF3                Cs-Cs                5.2
# 4937             CsNaS                Cs-Cs                5.2
# 4968           Cs2MnF6                Cs-Cs                5.2
# 4971           CsTiCl3                Cs-Cs                5.2
# 5036            Cs2Se5                Cs-Cs                5.2
# 5098           CsNiCl3                Cs-Cs                5.2
# 5113               CsF                Cs-Cs                5.2
# 5138           Cs2CuF6                Cs-Cs                5.2
# 5172           Cs3NiF7                Cs-Cs                5.2
# 5183           Cs3CrF7                Cs-Cs                5.2
# 5187           Cs3MnF7                Cs-Cs                5.2
# 5222              CsC8                Cs-Cs                5.2
# 5228         Cs(TeO3)2                Cs-Cs                5.2
# 5237         CsCu2ICl2                Cs-Cs                5.2
# 5258           Cs2PbO3                Cs-Cs                5.2
# 5269           Cs2CoF6                Cs-Cs                5.2
# 5286           CsGeCl3                Cs-Cs                5.2
# 5335            CsAlF4                Cs-Cs                5.2
# 5379          CsAg5Se3                Cs-Cs                5.2
# 5390             CsGa7                Cs-Cs                5.2
# 5437           CsLiSO4                Cs-Cs                5.2
# 5447       CsSr2Nb3O10                Cs-Cs                5.2
# 5452         Cs7Cu6F19                Cs-Cs                5.2
# 5469         Cs7Fe4F15                Cs-Cs                5.2
# 5541          Cs2LiNF6                Cs-Cs                5.2
# 5564          Cs2NaNF6                Cs-Cs                5.2
# 5599           CsCrCl3                Cs-Cs                5.2
# 5635            CsSO2F                Cs-Cs                5.2
# 5674          Cs3MnBr5                Cs-Cs                5.2
# 5773            CsMnSb                Cs-Cs                5.2
# 5822             CsAgO                Cs-Cs                5.2
# 5865             CsNO2                Cs-Cs                5.2
# 5882        Cs4Si2CuO7                Cs-Cs                5.2
# 5891        Cs3Na2SnP3                Cs-Cs                5.2
# 5915         Cs2NaMnF6                Cs-Cs                5.2
# 5946        Cs4U2V2O13                Cs-Cs                5.2
# 5955          Cs2Mn3S4                Cs-Cs                5.2
# 5956          Cs2Co3S4                Cs-Cs                5.2
# 5959          Cs2MnTe2                Cs-Cs                5.2
# 5963          Cs2MnSe2                Cs-Cs                5.2
# 6013          Cs5SiAs3                Cs-Cs                5.2
# 6015          Cs5GeAs3                Cs-Cs                5.2
# 6114            CsFeF3                Cs-Cs                5.2
# 6140           Cs2ZrO3                Cs-Cs                5.2
# 6142         CsErCdTe3                Cs-Cs                5.2
# 6161           Cs2CoS2                Cs-Cs                5.2
# 6244          CsSi2HO5                Cs-Cs                5.2
# 6370            CsSnI3                Cs-Cs                5.2
# 6383        Cs2Li3GaO4                Cs-Cs                5.2
# 6408            CsMnF4                Cs-Cs                5.2
# 6409            Cs2Se3                Cs-Cs                5.2
# 6439           Cs2SeO4                Cs-Cs                5.2
# 6440           CsSb2F7                Cs-Cs                5.2
# 6449           Cs2MnF5                Cs-Cs                5.2
# 6464           Cs4HfO4                Cs-Cs                5.2
# 6522           Cs2MnO4                Cs-Cs                5.2
# 6696        CsLa2CuSe4                Cs-Cs                5.2
# 6761           Cs2HgF4                Cs-Cs                5.2
# 6819            CsNbN2                Cs-Cs                5.2
# 6888            CsAuSe                Cs-Cs                5.2
# 6892            CsTeAu                Cs-Cs                5.2
# 6925            CsCuO2                Cs-Cs                5.2
# 6949            CsGdO3                Cs-Cs                5.2
# 6959            CsBiS2                Cs-Cs                5.2
# 6988            CsSnS3                Cs-Cs                5.2
# 7055          Cs6Fe2O5                Cs-Cs                5.2
# 7070            CsHgF3                Cs-Cs                5.2
# 7075           Cs2CaO2                Cs-Cs                5.2
# 7094            CsPrS2                Cs-Cs                5.2
# 7098            CsErS2                Cs-Cs                5.2
# 7099            CsHoS2                Cs-Cs                5.2
# 7103            CsPrS2                Cs-Cs                5.2
# 7108            CsTmS2                Cs-Cs                5.2
# 7109            CsDyS2                Cs-Cs                5.2
# 7110            CsCeS2                Cs-Cs                5.2
# 7117            CsLaS2                Cs-Cs                5.2
# 7133            CsNdS2                Cs-Cs                5.2
# 7197            CsReO4                Cs-Cs                5.2
# 7232            CsBrO3                Cs-Cs                5.2
# 7265         Cs(FeAs)2                Cs-Cs                5.2
# 7402           CsZnPO4                Cs-Cs                5.2
# 7463            Cs3AuO                Cs-Cs                5.2
# 7470             Cs2Se                Cs-Cs                5.2
# 7480         Cs7Ni4F15                Cs-Cs                5.2
# 7484       Cs2ZrCu3F12                Cs-Cs                5.2
# 7541           Cs2V4O9                Cs-Cs                5.2
# 7586        CsNb(BO3)2                Cs-Cs                5.2
# 7610           Cs2AgF4                Cs-Cs                5.2
# 7666         Cs2Mn3Se4                Cs-Cs                5.2
# 7763            CsMnF4                Cs-Cs                5.2
# 7829        CsTa(BO3)2                Cs-Cs                5.2
# 7934          Cs2NaVF6                Cs-Cs                5.2
# 7943           Cs3SiF7                Cs-Cs                5.2
# 8019         CsLaNb2O7                Cs-Cs                5.2
# 8021           Cs3MgH5                Cs-Cs                5.2
# 8047           Cs2CaF4                Cs-Cs                5.2
# 8128              CsTe                Cs-Cs                5.2
# 8193             CsNO3                Cs-Cs                5.2
# 8202              CsSi                Cs-Cs                5.2
# 8217           CsAuSe3                Cs-Cs                5.2
# 8220             CsBrF                Cs-Cs                5.2
# 8244        Cs2KMn3F12                Cs-Cs                5.2
# 8245           Cs3BAs2                Cs-Cs                5.2
# 8317           CsTeSe3                Cs-Cs                5.2
# 8358          Cs6ZnGe8                Cs-Cs                5.2
# 8363           CsCdCl3                Cs-Cs                5.2
# 8434          CsCdAuS2                Cs-Cs                5.2
# 8695          Cs2SnAs2                Cs-Cs                5.2
# 8712          CsSbClF3                Cs-Cs                5.2
# 8728      Cs3Mo2(O2F)3                Cs-Cs                5.2
# 8757             CsSO3                Cs-Cs                5.2
# 8782          Cs3CoBr5                Cs-Cs                5.2
# 8788            CsFeS2                Cs-Cs                5.2
# 8813         Cs2LiGaF6                Cs-Cs                5.2
# 8824            CsSbF4                Cs-Cs                5.2
# 8829       Cs4CdNi3F12                Cs-Cs                5.2
# 8840            CsVCl3                Cs-Cs                5.2
# 8915           Cs3GeF7                Cs-Cs                5.2
# 8966           Cs3AlP2                Cs-Cs                5.2
# 8975            CsLiF2                Cs-Cs                5.2
# 9009          Cs2CrCl4                Cs-Cs                5.2
# 9015           CsFeCl3                Cs-Cs                5.2
# 9066          Cs2Te3As                Cs-Cs                5.2
# 9087          Cs3SbSe4                Cs-Cs                5.2
# 9238           CsGaTe2                Cs-Cs                5.2
# 9255           Cs3BiO3                Cs-Cs                5.2
# 9302           CsSnSe3                Cs-Cs                5.2
# 9322          Cs2PdCl4                Cs-Cs                5.2
# 9324           Cs3MnI5                Cs-Cs                5.2
# 9332      Cs2Ti(GeO3)3                Cs-Cs                5.2
# 9339         Cs4Re6S13                Cs-Cs                5.2
# 9362       Cs2CrH2Cl5O                Cs-Cs                5.2
# 9367            Cs3YF6                Cs-Cs                5.2
# 9374           Cs3TlF6                Cs-Cs                5.2
# 9409             CsHg2                Cs-Cs                5.2
# 9456          Cs2ZrSe3                Cs-Cs                5.2
# 9486           CsNaGe2                Cs-Cs                5.2
# 9774             CsAuO                Cs-Cs                5.2
# 9837           Cs4IrO4                Cs-Cs                5.2
# 9854           Cs2SiP2                Cs-Cs                5.2
# 9958              CsCl                Cs-Cs                5.2
# 9986               CsF                Cs-Cs                5.2
# 9987              CsBr                Cs-Cs                5.2
# 10070       CsAg(NO3)2                Cs-Cs                5.2
# 10082         Cs2TlVF6                Cs-Cs                5.2
# 10136           CsAgC2                Cs-Cs                5.2
# 10209          CsScBr3                Cs-Cs                5.2
# 10297          Cs2NbF6                Cs-Cs                5.2
# 10327             Cs2O                Cs-Cs                5.2
# 10335               Cs                Cs-Cs                5.2
# 10342             Cs2O                Cs-Cs                5.2
# 10517           CsCaF3                Cs-Cs                5.2
# 10651       Cs2Al2P2O9                Cs-Cs                5.2
# 10713      CsCa2Ta3O10                Cs-Cs                5.2
# 10717       CsBe2BO3F2                Cs-Cs                5.2
# 10788            Cs3Sb                Cs-Cs                5.2
# 10793          Cs2PdI6                Cs-Cs                5.2
# 10798         CsTiAsO5                Cs-Cs                5.2
# 10861               Cs                Cs-Cs                5.2
# 10870           CsReF8                Cs-Cs                5.2
# 10889       Cs6Si2NiO8                Cs-Cs                5.2
# 10948         Cs7Au5O2                Cs-Cs                5.2
# 11119          Cs2SiF6                Cs-Cs                5.2
# 11128    Cs2Ti(CuSe2)2                Cs-Cs                5.2
# 11147        Cs2TlFeF6                Cs-Cs                5.2
# 11174         CsAlCuF6                Cs-Cs                5.2
# 11204      Cs5Nb2S4Cl9                Cs-Cs                5.2
# 11256         CsUCuSe3                Cs-Cs                5.2
# 11259        CsHoZnSe3                Cs-Cs                5.2
# 11271        CsSmZnSe3                Cs-Cs                5.2
# 11281           Cs2SO4                Cs-Cs                5.2
# 11288        CsErZnSe3                Cs-Cs                5.2
# 11294    Cs4NaHf3H2F19                Cs-Cs                5.2
# 11322         Cs3P6N11                Cs-Cs                5.2
# 11326           CsSnF3                Cs-Cs                5.2
# 11344         Cs6Si2O7                Cs-Cs                5.2
# 11403       CsEr2Cu3S5                Cs-Cs                5.2
# 11441         Yb3CsSe4                Cs-Cs                5.2
# 11452       Cs2AlP3O10                Cs-Cs                5.2
# 11613           CsCaO3                Cs-Cs                5.2
# 11693          Cs2PdF6                Cs-Cs                5.2
# 11877           TbCsF5                Cs-Cs                5.2
# 11991           Cs3As7                Cs-Cs                5.2
# 12014           CsBSe3                Cs-Cs                5.2
# 12016       Cs5Si3AgO9                Cs-Cs                5.2
# 12040         Cs6Ti2O7                Cs-Cs                5.2
# 12102         Cs2SnTe4                Cs-Cs                5.2
# 12110      CsSr2Ta3O10                Cs-Cs                5.2
# 12166        Cs2CoSiO4                Cs-Cs                5.2
# 12291          CsCu5S3                Cs-Cs                5.2
# 12295          Cs2PtC2                Cs-Cs                5.2
# 12304          Cs2PdC2                Cs-Cs                5.2
# 12368           Cs2UO4                Cs-Cs                5.2
# 12417          Cs2SnF6                Cs-Cs                5.2
# 12418         CsSiBiS4                Cs-Cs                5.2
# 12427         CsGeBiS4                Cs-Cs                5.2
# 12430   CsC2S2N(O2F3)2                Cs-Cs                5.2
# 12438       Cs2GaP3O10                Cs-Cs                5.2
# 12491      Cs7NbIn3As5                Cs-Cs                5.2
# 12501         CsErSiS4                Cs-Cs                5.2
# 12522         CsSmSiS4                Cs-Cs                5.2
# 12524         CsGdSiS4                Cs-Cs                5.2
# 12546        Cs2NaCaF6                Cs-Cs                5.2
# 12566          Cs3CeF6                Cs-Cs                5.2
# 12708         CsYCdSe3                Cs-Cs                5.2
# 12712        CsNdHgSe3                Cs-Cs                5.2
# 12714        CsDyCdSe3                Cs-Cs                5.2
# 12717        CsPrHgSe3                Cs-Cs                5.2
# 12718        CsSmHgSe3                Cs-Cs                5.2
# 12745       Cs3AlGe2O7                Cs-Cs                5.2
# 12763          CsSb2F7                Cs-Cs                5.2
# 12777      CsTmSeCl2O3                Cs-Cs                5.2
# 12827            CsBF4                Cs-Cs                5.2
# 12867         Cs(MnP)2                Cs-Cs                5.2
# 12895         Cs6Bi4O9                Cs-Cs                5.2
# 13120            CsBi2                Cs-Cs                5.2
# 13151          Cs2PtF6                Cs-Cs                5.2
# 13155           CsInF3                Cs-Cs                5.2
# 13337            CsPS3                Cs-Cs                5.2
# 13445        Cs3Ru2Cl9                Cs-Cs                5.2
# 13524           CsIrO3                Cs-Cs                5.2
# 13651           CsNiF3                Cs-Cs                5.2
# 13808          Cs2CaH4                Cs-Cs                5.2
# 13897       Cs2CdBi2S5                Cs-Cs                5.2
# 14000          Cs2PSe5                Cs-Cs                5.2
# 14015          CsIn3O5                Cs-Cs                5.2
# 14083         Cs2Pd3S4                Cs-Cs                5.2
# 14132           CsSbO2                Cs-Cs                5.2
# 14133    Cs3Mn4(PO3)12                Cs-Cs                5.2
# 14195          CsNdTe2                Cs-Cs                5.2
# 14382            Cs6K7                Cs-Cs                5.2
# 14408           CsSmO2                Cs-Cs                5.2
# 14438      CsDy2Cu3Se5                Cs-Cs                5.2
# 14665         Cs3Ge4Au                Cs-Cs                5.2
# 14674      Cs5CaNi4F15                Cs-Cs                5.2
# 14708             CsSn                Cs-Cs                5.2
# 14859         Cs2Ge2S5                Cs-Cs                5.2
# 14870           CsMgH3                Cs-Cs                5.2
# 14875         Cs2SiSe4                Cs-Cs                5.2
# 14919          Cs2PbO3                Cs-Cs                5.2
# 14931             CsSi                Cs-Cs                5.2
# 14966         Cs2Sn2O3                Cs-Cs                5.2
# 15073           CsBiO3                Cs-Cs                5.2
# 15120           CsGaS2                Cs-Cs                5.2
# 15331          Cs3TaS4                Cs-Cs                5.2
# 15337         Cs4U5O17                Cs-Cs                5.2
# 15378        CsSmZnTe3                Cs-Cs                5.2
# 15386         Cs2Pt3S4                Cs-Cs                5.2
# 15387        CsDyZnTe3                Cs-Cs                5.2
# 15389        CsErZnTe3                Cs-Cs                5.2
# 15396        TbCsZnTe3                Cs-Cs                5.2
# 15397        CsLaZnTe3                Cs-Cs                5.2
# 15400        CsHoZnTe3                Cs-Cs                5.2
# 15476            CsIn3                Cs-Cs                5.2
# 15499          CsH2CO3                Cs-Cs                5.2
# 15640    Cs2Cu3(P2O7)2                Cs-Cs                5.2
# 15672            CsBO2                Cs-Cs                5.2
# 15853         Cs2SeCl6                Cs-Cs                5.2
# 15875          Cs3ScO3                Cs-Cs                5.2
# 15878         Cs2TeCl6                Cs-Cs                5.2
# 15883        CsHoCdTe3                Cs-Cs                5.2
# 15887        CsSmCdTe3                Cs-Cs                5.2
# 15895        CsTmCdTe3                Cs-Cs                5.2
# 15899           CsNaF3                Cs-Cs                5.2
# 15902        CsPrCdTe3                Cs-Cs                5.2
# 16050       Cs2UHg2Se5                Cs-Cs                5.2
# 16174           CsBrO4                Cs-Cs                5.2
# 16337          CsCoCl3                Cs-Cs                5.2
# 16363         Cs2AgBr3                Cs-Cs                5.2
# 16374        Cs3Cu2Cl5                Cs-Cs                5.2
# 16393      Cs2Sn(H2N)6                Cs-Cs                5.2
# 16552        Cs4UC3O11                Cs-Cs                5.2
# 16567         Cs3Fe2F9                Cs-Cs                5.2
# 16573           CsAuF4                Cs-Cs                5.2
# 16600      Cs2Th(PS3)3                Cs-Cs                5.2
# 16705          Cs2BeF4                Cs-Cs                5.2
# 16767          YbCsSe2                Cs-Cs                5.2
# 16777          Cs2PrO3                Cs-Cs                5.2
# 16806      Cs2Al2Sb2O7                Cs-Cs                5.2
# 16812          Cs(CO)2                Cs-Cs                5.2
# 16813      Cs2Al2As2O7                Cs-Cs                5.2
# 16849           CsAlO2                Cs-Cs                5.2
# 17014       Cs3GeAsSe5                Cs-Cs                5.2
# 17265          Cs2CrF6                Cs-Cs                5.2
# 17398       Cs2MnSnTe4                Cs-Cs                5.2
# 17436         Cs2Sr2O3                Cs-Cs                5.2
# 17496       Cs4Sb14S23                Cs-Cs                5.2
# 17506      Cs2Co(PO3)4                Cs-Cs                5.2
# 17510           Cs3PO4                Cs-Cs                5.2
# 17574         Cs4SiSe4                Cs-Cs                5.2
# 17644         Cs3Cu5O4                Cs-Cs                5.2
# 17660            CsCO2                Cs-Cs                5.2
# 17677         CsLi3Br4                Cs-Cs                5.2
# 17682        Cs2Mo2O11                Cs-Cs                5.2
# 17713       Cs2GeP4O13                Cs-Cs                5.2
# 17762        Cs4Ta2S11                Cs-Cs                5.2
# 17856         CsPH3O4F                Cs-Cs                5.2
# 17862        Cs(SbS2)2                Cs-Cs                5.2
# 17864      Cs2YSi4O10F                Cs-Cs                5.2
# 17938       CsNd(PO3)4                Cs-Cs                5.2
# 17982          CsZnPO4                Cs-Cs                5.2
# 18055       Cs2Na2IrO4                Cs-Cs                5.2
# 18060  Cs12Nb(In2As3)3                Cs-Cs                5.2
# 18080       CsAlBP2HO9                Cs-Cs                5.2
# 18097          Cs3TiF7                Cs-Cs                5.2
# 18106      Tb6Cs2Te7N2                Cs-Cs                5.2
# 18484        Cs2Re2Se5                Cs-Cs                5.2
# 18567       CsPr(PO3)4                Cs-Cs                5.2
# 18572         CsHo3Te5                Cs-Cs                5.2
# 18624             CsSb                Cs-Cs                5.2
# 18642          CsHSeO4                Cs-Cs                5.2
# 18655          Cs2CrO4                Cs-Cs                5.2
# 18662          Cs3TaO8                Cs-Cs                5.2
# 18714        Cs4Ga2Se5                Cs-Cs                5.2
# 18808     Cs2Si8Cu2O19                Cs-Cs                5.2
# 18817        Cs2In2Sb3                Cs-Cs                5.2
# 18836        CsLaHgSe3                Cs-Cs                5.2
# 18903        Cs3Ta5O14                Cs-Cs                5.2
# 18907          Cs2GeF6                Cs-Cs                5.2
# 19064         Cs2Sb4S7                Cs-Cs                5.2
# 19116         Cs4P2Se9                Cs-Cs                5.2
# 19154          CsCu2F5                Cs-Cs                5.2
# 19199        Cs4V2S4O3                Cs-Cs                5.2
# 19217          CsGa3S5                Cs-Cs                5.2
# 19218        Cs2SrP2O7                Cs-Cs                5.2
# 19279           CsHSO4                Cs-Cs                5.2
# 19287       Cs2Ga2B2O7                Cs-Cs                5.2
# 19347           CsSbS2                Cs-Cs                5.2
# 19382      CsPr(MoO4)2                Cs-Cs                5.2
# 19396          Cs3TmO3                Cs-Cs                5.2
# 19398         CsCr5Se8                Cs-Cs                5.2
# 19423         CsK4GaO4                Cs-Cs                5.2
# 19508          Cs4SnO4                Cs-Cs                5.2
# 19510       Cs4Re6Se13                Cs-Cs                5.2
# 19583         Cs3V2Cl9                Cs-Cs                5.2
# 19645           CsSnF3                Cs-Cs                5.2
# 19646         CsFeP2O7                Cs-Cs                5.2
# 19654          CsSiTe3                Cs-Cs                5.2
# 19680       CsLi(PO3)2                Cs-Cs                5.2
# 19941        Cs4Tc6S13                Cs-Cs                5.2
# 19963       CsEr(PO3)4                Cs-Cs                5.2
# 19986         Cs2Ni3S4                Cs-Cs                5.2
# 20112         Cs2LiVO4                Cs-Cs                5.2
# 20131               Cs                Cs-Cs                5.2
# 20140       Cs2NbAgSe4                Cs-Cs                5.2
# 20165         Cs2VAgS4                Cs-Cs                5.2
# 20185         Cs3HgCl5                Cs-Cs                5.2
# 20196            Cs2P3                Cs-Cs                5.2
# 20201          Cs4ZrO4                Cs-Cs                5.2
# 20211          CsAsSe2                Cs-Cs                5.2
# 20231           EuCsF3                Cs-Cs                5.2
# 20269      Cs2Mn(PO3)4                Cs-Cs                5.2
# 20279       Cs2K4Fe2O5                Cs-Cs                5.2
# 20293         Cs2ZnN12                Cs-Cs                5.2
# 20339      Cs5Mo21Se23                Cs-Cs                5.2
# 20399      Cs2NaAl3F12                Cs-Cs                5.2
# 20403     Cs4Nb2Si8O23                Cs-Cs                5.2
# 20412          Cs2TeO3                Cs-Cs                5.2
# 20434        Cs11Rb7O3                Cs-Cs                5.2
# 20437    Tb3Cs2Li14O14                Cs-Cs                5.2
# 20447          Cs3AlO3                Cs-Cs                5.2
# 20613            CsC10                Cs-Cs                5.2
# 20657      Cs3Mo15Se17                Cs-Cs                5.2
# 20658        Cs2NaTiF6                Cs-Cs                5.2
# 20667         CsPt2Se3                Cs-Cs                5.2
# 20725         Cs2Re2S5                Cs-Cs                5.2
# 20781            Cs3P7                Cs-Cs                5.2
# 20795       CsPr(CO3)2                Cs-Cs                5.2
# 20823           CsAlF4                Cs-Cs                5.2
# 20967          Cs3LaO3                Cs-Cs                5.2
# 20970           CsGdS2                Cs-Cs                5.2
# 20980           CsLuS2                Cs-Cs                5.2
# 20985       Cs2Na3TlO4                Cs-Cs                5.2
# 21036         CsNiPdF5                Cs-Cs                5.2
# 21048    Cs5Te3H4NCl18                Cs-Cs                5.2
# 21069          CsYP2O7                Cs-Cs                5.2
# 21106      Cs4Sc6CCl13                Cs-Cs                5.2
# 21165      YbCs3(SO4)3                Cs-Cs                5.2
# 21181         Cs3Ga2F9                Cs-Cs                5.2
# 21221          CsPbBr3                Cs-Cs                5.2
# 21284       Cs3(FeS2)2                Cs-Cs                5.2
# 21391         CsAlSiO4                Cs-Cs                5.2
# 21418   Cs4Li2(Si2O5)3                Cs-Cs                5.2
# 21420         Cs2Si2O5                Cs-Cs                5.2
# 21438        Cs2TlMoF6                Cs-Cs                5.2
# 21501           CsH5O3                Cs-Cs                5.2
# 21515           CsCrF4                Cs-Cs                5.2
# 21529     Cs4KLiGa2F12                Cs-Cs                5.2
# 21531     Cs4KLiFe2F12                Cs-Cs                5.2
# 21534         Cs2GeTe4                Cs-Cs                5.2
# 21621         CsAlPdF6                Cs-Cs                5.2
# 21675      CsDy(MoO4)2                Cs-Cs                5.2
# 21720     Cs2Na2B10O17                Cs-Cs                5.2
# 21853          CsSbOF4                Cs-Cs                5.2
# 21915       Cs2NbCuSe4                Cs-Cs                5.2
# 21929        Cs2TaAgS4                Cs-Cs                5.2
# 21934      CsAl(SiO3)2                Cs-Cs                5.2
# 22028         Cs3BiSe3                Cs-Cs                5.2
# 22045          CsZnPO4                Cs-Cs                5.2
# 22161         Cs2PtCl4                Cs-Cs                5.2
# 22162        Cs2NaCrF6                Cs-Cs                5.2
# 22179       Cs(SbSe2)2                Cs-Cs                5.2
# 22273    Cs2Co2(MoO4)3                Cs-Cs                5.2
# 22274          CsAs3O8                Cs-Cs                5.2
# 22324        Cs2NaFeF6                Cs-Cs                5.2
# 22398        Cs2AgAsS4                Cs-Cs                5.2
# 22408         CsLuP2O7                Cs-Cs                5.2
# 22441      CsCa2Nb3O10                Cs-Cs                5.2
# 22475         Cs3BiCl6                Cs-Cs                5.2
# 22484         Cs3AlAs2                Cs-Cs                5.2
# 22559         Cs3GaAs2                Cs-Cs                5.2
# 22570             Cs2S                Cs-Cs                5.2
# 22589         Cs2GaSb2                Cs-Cs                5.2
# 22615       Cs6K3AlSb4                Cs-Cs                5.2
# 22732       Cs3ZnI4NO3                Cs-Cs                5.2
# 22916     Cs2Sn(AuS2)2                Cs-Cs                5.2
# 22954       Cs6K3GaSb4                Cs-Cs                5.2
# 22975      Cs5Nb2S4Br9                Cs-Cs                5.2
# 22986     Cs2CeAsS3Cl2                Cs-Cs                5.2
# 23098        Cs2NaCoF6                Cs-Cs                5.2
# 23102          CsAgCl2                Cs-Cs                5.2
# 23197             CsGe                Cs-Cs                5.2
# 23302    Cs2Ti(Si2O5)3                Cs-Cs                5.2
# 23374        CsBC3NOF9                Cs-Cs                5.2
# 23384      Cs2Co(NO3)4                Cs-Cs                5.2
# 23487          Cs2NiF6                Cs-Cs                5.2
# 23661        CsPrCdSe3                Cs-Cs                5.2
# 23706          Cs2TeO4                Cs-Cs                5.2
# 23867           Cs2Te3                Cs-Cs                5.2
# 23882         Cs2Zn3S4                Cs-Cs                5.2
# 23901         CsTiP2O7                Cs-Cs                5.2
# 23921     Cs5Ti6AgSe27                Cs-Cs                5.2
# 23950         Cs4SiTe4                Cs-Cs                5.2
# 23956         Cs2Ti2S9                Cs-Cs                5.2
# 24015    Cs2Ti(Si2O5)3                Cs-Cs                5.2
# 24016          CsPdCl3                Cs-Cs                5.2
# 24102         CsBa2Br5                Cs-Cs                5.2
# 24162        Cs4Ti3S14                Cs-Cs                5.2
# 24173          Cs2ZnO2                Cs-Cs                5.2
# 24197          Cs2CoO3                Cs-Cs                5.2
# 24199    Cs3Cu2(BiS2)5                Cs-Cs                5.2
# 24239          CsMnCl3                Cs-Cs                5.2
# 24244          CsCuCl3                Cs-Cs                5.2
# 24254         CsYZnSe3                Cs-Cs                5.2
# 24305        CsZrCuSe3                Cs-Cs                5.2
# 24321        CsTmZnSe3                Cs-Cs                5.2
# 24334        YbCsZnSe3                Cs-Cs                5.2
# 24383        Cs10Si7O9                Cs-Cs                5.2
# 24387         Cs2TeOF4                Cs-Cs                5.2
# 24389          Cs6Cl4O                Cs-Cs                5.2
# 24406        Cs8Ta6O19                Cs-Cs                5.2
# 24408          CsMoPO6                Cs-Cs                5.2
# 24422           Cs3BS3                Cs-Cs                5.2
# 24424          Cs2CeO3                Cs-Cs                5.2
# 24663          CsCuCl3                Cs-Cs                5.2
# 24895      CsCu(BiS2)2                Cs-Cs                5.2
# 24911      Cs2Ni(PS3)2                Cs-Cs                5.2
# 24937      Tb2CsAg3Se5                Cs-Cs                5.2
# 25045       Cs2AgAuCl6                Cs-Cs                5.2
# 25068      CsMnMo(OF)3                Cs-Cs                5.2
# 25087           CsBr2F                Cs-Cs                5.2
# ...
# 49240         4.527536        716.081243       12.0  58a7a4f17f079f2fd3b92d67
# 49258         3.875299        986.516518       20.0  58a7a4f37f079f2fd3b92d79
# 49444         4.335597       2911.871104       72.0  58a7a50e7f079f2fd3b92e33
# 49563         3.865185       2476.416088       36.0  58a7a5207f079f2fd3b92eaa
# 49605         3.946092        554.502023        6.0  58a7a5267f079f2fd3b92ed4
# 50008         3.902380       1443.858382       20.0  58a7a5637f079f2fd3b93067
# 50093         3.828708       1358.881346       24.0  58a7a5707f079f2fd3b930bc
# 50181         3.855285       4811.788857       72.0  58a7a57e7f079f2fd3b93114
# 50182         3.777977       3743.900420       64.0  58a7a57e7f079f2fd3b93115
# 50346         4.587668       1063.713034       18.0  58a7a5987f079f2fd3b931b9
# 50373         3.652298       2287.945481       40.0  58a7a59c7f079f2fd3b931d4
# 50536         3.744434       2433.816997       36.0  58a7a5b77f079f2fd3b93277
# 50594         3.517604       1233.801538       14.0  58a7a5c27f079f2fd3b932b1
# 50651         3.689997        360.639852        5.0  58a7a5ca7f079f2fd3b932ea
# 50679         4.583113        281.216000       10.0  58a7a5ce7f079f2fd3b93306
# 50730         3.706760        736.770392       12.0  58a7a5d57f079f2fd3b93339
# 50856         4.763655       1665.789464       36.0  58a7a5e87f079f2fd3b933b7
# 50858         3.909906        819.227043       14.0  58a7a5e87f079f2fd3b933b9
# 51111         4.503500        876.466992       19.0  58a7a60e7f079f2fd3b934b6
# 51197         4.511524        140.608000        5.0  58a7a61b7f079f2fd3b9350c
# 51236         3.880109       1436.525928       20.0  58a7a6217f079f2fd3b93533
# 51312         4.126748        237.975565        4.0  58a7a62d7f079f2fd3b9357f
# 51461         4.216426       1174.108557       28.0  58a7a6427f079f2fd3b93614
# 51491         4.885884        281.216000       10.0  58a7a6477f079f2fd3b93632
# 51629         4.141001       1333.507153       24.0  58a7a65a7f079f2fd3b936bc
# 55456         3.955999        703.803578        6.0  58a7a8997f079f2fd3b945af
# 57126         3.705887        455.962787        8.0  58a7a98d7f079f2fd3b94c35
# 57174         4.848894        200.109435        6.0  58a7a9947f079f2fd3b94c65
# 57514         4.439084        281.216000       10.0  58a7a9c57f079f2fd3b94db9
# 57639         4.415419        140.608000        5.0  58a7a9d67f079f2fd3b94e36
# 57754         4.496777        543.670735       21.0  58a7a9e77f079f2fd3b94ea9
# 57895         3.969311       2941.726262       32.0  58a7a9fb7f079f2fd3b94f36
# 58187         3.519801        473.897486        8.0  58a7aa257f079f2fd3b9505a
# 58204         4.021884        686.217730       12.0  58a7aa277f079f2fd3b9506b
# 58225         4.043075        830.768451       14.0  58a7aa2a7f079f2fd3b95080
# 58716         4.270204        852.925405       16.0  58a7aa707f079f2fd3b9526b
# 59537         4.064553        140.608000        5.0  58a7aae47f079f2fd3b955a0
# 59701         4.579710        419.978866        8.0  58a7aafb7f079f2fd3b95644
# 59917         3.842831       1957.331679       32.0  58a7ab1b7f079f2fd3b9571c
# 59930         4.045163        516.170761        9.0  58a7ab1d7f079f2fd3b95729
# 59936         4.076343        507.717013        9.0  58a7ab1e7f079f2fd3b9572f
# 59938         3.863039        563.684851        9.0  58a7ab1e7f079f2fd3b95731
# 60114         4.036708        826.221774       20.0  58a7ab387f079f2fd3b957e1
# 60190         4.087391       1056.827257       22.0  58a7ab437f079f2fd3b9582d
# 60308         4.199585        234.405862        4.0  58a7ab557f079f2fd3b958a3
# 60389         4.618953       1747.205144       56.0  58a7ab617f079f2fd3b958f4
# 60403         4.588874       1156.530294       28.0  58a7ab637f079f2fd3b95902
# 60483         3.800080       1992.306118       36.0  58a7ab707f079f2fd3b95952
# 60497         4.636110       4359.370747       80.0  58a7ab727f079f2fd3b95960
# 60501         3.754548       2157.721236       28.0  58a7ab737f079f2fd3b95964
# 60744         4.789933        139.557949        5.0  58a7ab987f079f2fd3b95a57
# 60783         4.014090       1137.137472       22.0  58a7ab9e7f079f2fd3b95a7e
# 60810         4.386983       1714.983963       56.0  58a7aba27f079f2fd3b95a99
# 60877         4.606904       1235.666826       46.0  58a7abab7f079f2fd3b95adc
# 61086         3.505688        475.827720        8.0  58a7abd97f079f2fd3b95bad
# 61168         3.948086        290.858699        5.0  58a7abe57f079f2fd3b95bff
# 61197         5.287151        281.216000        9.0  58a7abeb7f079f2fd3b95c1c
# 61283         4.284196       1364.762437       22.0  58a7abfb7f079f2fd3b95c72
# 61414         4.223215       1072.963464       17.0  58a7ac0f7f079f2fd3b95cf5
# 61443         4.090235        834.478408       30.0  58a7ac137f079f2fd3b95d12
# 61501         4.065118        747.017020       10.0  58a7ac1c7f079f2fd3b95d4c
# 61521         4.333645        671.442136       23.0  58a7ac1f7f079f2fd3b95d60
# 61589         4.019339       2452.195463       60.0  58a7ac2a7f079f2fd3b95da4
# 61619         3.611416       1325.518148       20.0  58a7ac2f7f079f2fd3b95dc2
# 61733         3.792268        999.848679       12.0  58a7ac457f079f2fd3b95e34
# 61798         3.795686       1901.678772       28.0  58a7ac507f079f2fd3b95e75
# 61935         4.763062        530.284173       17.0  58a7ac647f079f2fd3b95efe
# 61951         4.190985        715.979304       12.0  58a7ac677f079f2fd3b95f0e
# 62006         3.806781       5614.275919       24.0  58a7ac717f079f2fd3b95f45
# 62078         4.560432        700.203449       12.0  58a7ac7c7f079f2fd3b95f8d
# 62144         4.356130       2145.976129      124.0  58a7ac8a7f079f2fd3b95fcf
# 62158         5.094817        957.025980       28.0  58a7ac8d7f079f2fd3b95fdd
# 62179         4.152504       1333.421750       34.0  58a7ac917f079f2fd3b95ff2
# 62235         3.897374       1242.175327       24.0  58a7ac9c7f079f2fd3b9602a
# 62527         4.546934        546.433549       10.0  58a7acc97f079f2fd3b9614e
# 62630         3.958747       1344.963883       40.0  58a7acd77f079f2fd3b961b5
# 62669         3.725302       1865.529807       32.0  58a7acdd7f079f2fd3b961dc
# 62998         4.946481       1834.971584       48.0  58a7ad147f079f2fd3b96325
# 63176         3.736132       1305.954190       38.0  58a7ad317f079f2fd3b963d7
# 63192         4.700351        603.162374       16.0  58a7ad337f079f2fd3b963e7
# 63215         4.229912        674.518815       10.0  58a7ad377f079f2fd3b963fe
# 63303         3.938663        432.960355        8.0  58a7ad457f079f2fd3b96456
# 63530         4.552126        918.013295       20.0  58a7ad667f079f2fd3b96539
# 63536         4.351101       1119.761926       44.0  58a7ad687f079f2fd3b9653f
# 63613         4.362753        688.438899       12.0  58a7ad767f079f2fd3b9658c
# 63724         4.257345        723.534205       31.0  58a7ad8a7f079f2fd3b965fb
# 63727         4.549210        713.799072       12.0  58a7ad8a7f079f2fd3b965fe
# 63799         3.827900       2055.002762       28.0  58a7ad967f079f2fd3b96646
# 63839         3.709774       1035.053105       16.0  58a7ad9d7f079f2fd3b9666e
# 63913         4.993598         99.424883        2.0  58a7adaa7f079f2fd3b966b8
# 63970         4.607277        592.461311       10.0  58a7adb27f079f2fd3b966f1
# 63986         3.537647       1249.106936       14.0  58a7adb47f079f2fd3b96701
# 64101         4.039949        719.955260       10.0  58a7adc77f079f2fd3b96774
# 64140         3.541530       1242.878028       14.0  58a7adcd7f079f2fd3b9679b
# 64349         4.826598       1560.654001       36.0  58a7adf47f079f2fd3b9686c
# 64429         4.171647       1446.345126       16.0  58a7ae017f079f2fd3b968bc
# 64432         4.451524        432.960424       18.0  58a7ae017f079f2fd3b968bf
# 64517         5.468541        201.232487        2.0  58a7ae107f079f2fd3b96914
# 64565         4.088826        534.967142       12.0  58a7ae167f079f2fd3b96944
# 64684         4.358511        833.634451       24.0  58a7ae2a7f079f2fd3b969bb
# 64797         5.297727        281.216000        9.0  58a7ae3b7f079f2fd3b96a2c
# 64991         4.338830        358.139018        8.0  58a7ae5a7f079f2fd3b96aee
# 65087         3.581530       4491.663266       28.0  58a7ae687f079f2fd3b96b4e
# 65466         3.843377        237.962148        2.0  58a7ae9f7f079f2fd3b96cc9
# 66000         4.110154        476.392532        8.0  58a7aef07f079f2fd3b96ee1
# 66321         3.365542        957.315484       14.0  58a7af1f7f079f2fd3b97023
# 66422         3.175305        249.328450        2.0  58a7af2d7f079f2fd3b97088
# 66487         4.416457        281.216000       10.0  58a7af387f079f2fd3b970c9
# 66488         5.515873        281.216000       10.0  58a7af387f079f2fd3b970ca
# 66493         4.656136        281.216000       10.0  58a7af397f079f2fd3b970cf
# 66494         4.924710        281.216000       10.0  58a7af397f079f2fd3b970d0
# 66506         4.305440        281.216000       10.0  58a7af3b7f079f2fd3b970dc
# 66511         4.458625        281.216000       10.0  58a7af3b7f079f2fd3b970e1
# 66512         4.457373        281.216000       10.0  58a7af3c7f079f2fd3b970e2
# 66515         4.434778        281.216000       10.0  58a7af3c7f079f2fd3b970e5
# 66516         4.665760        281.216000       10.0  58a7af3c7f079f2fd3b970e6
# 66520         4.312959        281.216000       10.0  58a7af3d7f079f2fd3b970ea
# 66534         5.402155        281.216000       10.0  58a7af3e7f079f2fd3b970f8
# 66540         4.422041        281.216000       10.0  58a7af407f079f2fd3b970fe
# 66553         4.463617        281.216000       10.0  58a7af427f079f2fd3b9710b
# 66557         4.489427        281.216000       10.0  58a7af447f079f2fd3b9710f
# 66562         4.436028        281.216000       10.0  58a7af457f079f2fd3b97114
# 66563         4.816969        281.216000       10.0  58a7af457f079f2fd3b97115
# 66568         5.226274        281.216000       10.0  58a7af467f079f2fd3b9711a
# 66573         4.334420        281.216000       10.0  58a7af477f079f2fd3b9711f
# 66574         5.335791        281.216000       10.0  58a7af477f079f2fd3b97120
# 66596         5.165756        281.216000       10.0  58a7af4b7f079f2fd3b97136
# 66860         3.932323        261.017768        5.0  58a7af787f079f2fd3b9723e
# 67088         4.079042       1091.047934       32.0  58a7af9e7f079f2fd3b97322
# 67171         5.236661        474.690278        4.0  58a7afab7f079f2fd3b97375
# 67372         4.580074        281.216000       10.0  58a7afca7f079f2fd3b9743e
# 67426         4.248574       7773.691625      144.0  58a7afd47f079f2fd3b97474
# {'estimates': [4.4, 3.478085415898742], 'mp_values': [3.5941814145540349, 3.8101765393874909, 3.7249919112212879, 3.3619894172434499, 3.2440140995640974, 3.207992153917373, 3.6524354672926775, 3.2440362925885275, 3.8345990681626017, 3.2807020072381063]}
#                    name worst_predicted_bond  expected_distance  \
# 74        Cs2NaAl(PO4)2                Cs-Na                4.4
# 1849    Cs6Na2Nb6H36O37                Cs-Na                4.4
# 4380          Cs2NaMnF6                Cs-Na                4.4
# 7635           CsNaTiO3                Cs-Na                4.4
# 8800        CsNa5(WN3)2                Cs-Na                4.4
# 19165        Cs2Na3InO4                Cs-Na                4.4
# 21742         CsNaSi2O5                Cs-Na                4.4
# 33653          CsNa2BO3                Cs-Na                4.4
# 44903            CsNaF3                Cs-Na                4.4
# 49063  CsNa3Li12(GeO4)4                Cs-Na                4.4
#
#        actual_distance  predicted_volume  num_atoms                       _id
# 74            3.594181       3697.078095      112.0  58a781d37f079f2fd3b86d48
# 1849          3.810177       1660.445386       87.0  58a783bc7f079f2fd3b87439
# 4380          3.724992        604.342495       20.0  58a788667f079f2fd3b87e1d
# 7635          3.361989        440.009839       12.0  58a78a607f079f2fd3b88ad5
# 8800          3.244014       4816.156782      112.0  58a78b0c7f079f2fd3b88f62
# 19165         3.207992       2029.423546       40.0  58a7915e7f079f2fd3b8b7e6
# 21742         3.652435       2057.578476       72.0  58a793147f079f2fd3b8c1f7
# 33653         3.244036        525.309051       14.0  58a79b197f079f2fd3b8f080
# 44903         3.834599        144.824926        5.0  58a7a2577f079f2fd3b91c76
# 49063         3.280702       1016.244134       36.0  58a7a4d77f079f2fd3b92cb6
# {'estimates': [3.75, 2.8213425763106366], 'mp_values': [3.1258710635627232, 2.6362394492076864, 2.8213425763106366]}
#             name worst_predicted_bond  expected_distance  actual_distance  \
# 36958     KZr2Nb                 K-Zr               3.75         3.125871
# 38017  K(Zr3I7)4                 K-Zr               3.75         2.636239
# 48153  K(Zr3I7)2                 K-Zr               3.75         2.821343
#
#        predicted_volume  num_atoms                       _id
# 36958        162.379763        4.0  58a79d137f079f2fd3b8fd6b
# 38017      19665.305240      164.0  58a79db67f079f2fd3b9018f
# 48153       3893.736364       42.0  58a7a44f7f079f2fd3b92928
# {'estimates': [3.75, 2.811354530549105], 'mp_values': [2.8113545305491048]}
#         name worst_predicted_bond  expected_distance  actual_distance  \
# 37052  KHfNi                 Hf-K               3.75         2.811355
#
#        predicted_volume  num_atoms                       _id
# 37052        162.379763        3.0  58a79d217f079f2fd3b8fdca
# {'estimates': [1.0, 2.489434155303493], 'mp_values': [2.7952226578376052, 2.8186876691665743, 1.4273733345844997, 3.0676676257244013, 1.4267515944663114, 2.5350562783550425, 2.4438120322519432, 2.8779649777328848, 1.4263539833775516, 2.231050025, 1.4267712785023376, 2.5507755033773321]}
#        name worst_predicted_bond  expected_distance  actual_distance  \
# 11424  KrF2                  F-F                1.0         2.795223
# 13895  KrF2                  F-F                1.0         2.818688
# 14070    F2                  F-F                1.0         1.427373
# 14572  XeF2                  F-F                1.0         3.067668
# 16495    F2                  F-F                1.0         1.426752
# 28509  XeF6                  F-F                1.0         2.535056
# 33189  XeF6                  F-F                1.0         2.443812
# 48741  XeF3                  F-F                1.0         2.877965
# 51434    F2                  F-F                1.0         1.426354
# 52290    F2                  F-F                1.0         2.231050
# 54886    F2                  F-F                1.0         1.426771
# 67389  XeF6                  F-F                1.0         2.550776
#
#        predicted_volume  num_atoms                       _id
# 11424          2.933135        3.0  58a78cb57f079f2fd3b899a6
# 13895          6.034980        6.0  58a78e227f079f2fd3b8a350
# 14070         22.006291        4.0  58a78e3b7f079f2fd3b8a3ff
# 14572          2.515601        3.0  58a78e8a7f079f2fd3b8a5f5
# 16495         26.271550        4.0  58a78fb87f079f2fd3b8ad78
# 28509        115.301076      112.0  58a797b67f079f2fd3b8dc67
# 33189        135.696252      112.0  58a79ad27f079f2fd3b8eeb0
# 48741         14.110571       16.0  58a7a4a77f079f2fd3b92b74
# 51434         32.541423        4.0  58a7a63e7f079f2fd3b935f9
# 52290          8.000000        8.0  58a7a6bb7f079f2fd3b93951
# 54886         21.919076        4.0  58a7a8477f079f2fd3b94375
# 67389        116.034303      112.0  58a7afcd7f079f2fd3b9744f
# {'estimates': [1.42, 3.9881110173526872], 'mp_values': [3.988628004705375, 3.9875940299999999]}
#       name worst_predicted_bond  expected_distance  actual_distance  \
# 1771    Ar                Ar-Ar               1.42         3.988628
# 11783   Ar                Ar-Ar               1.42         3.987594
#
#        predicted_volume  num_atoms                       _id
# 1771           2.024650        1.0  58a783987f079f2fd3b873eb
# 11783          4.065892        2.0  58a78cee7f079f2fd3b89b0d

# %% [markdown]
# ## Test bench

# %%
len(bond_length_predictions)
# Out:
# 1

# %%
len(new_bonds_added_this_iter), new_bonds_added_this_iter[0]
# Out:
# (812, u'Ni-O')

# %%
for b in new_bonds_added_this_iter:
    del bonds[b]

# %%
bonds['Ni-O']
# Out:
# {'estimates': [1.9500000000000002],
#  'mp_values': [1.8805266150531745,
#   2.0558223685412003,
#   2.1098317445106076,
#   1.8724391943498615,
#   1.8826315845081569,
#   1.8143699626794569]}

# %%
cols = ['name', 'worst_predicted_bond', 'expected_distance', 'actual_distance', 'predicted_volume',
        'num_atoms', '_id']
bl_pred_2 = pd.DataFrame(bond_length_predictions[0], columns=cols)

# %%
display(bl_pred_1[bl_pred_1['worst_predicted_bond']=='Ni-O'])
# Out:
#                    name worst_predicted_bond  expected_distance  \
# 0                 Ni3O4                 Ni-O               1.95
# 201   NiH44C12N8(ClO5)2                 Ni-O               1.95
# 1420                NiO                 Ni-O               1.95
# 2073            Co2NiO6                 Ni-O               1.95
# 2328         Li2MnNi3O8                 Ni-O               1.95
# 2343               NiO2                 Ni-O               1.95
#
#       actual_distance  predicted_volume  num_atoms                       _id
# 0            1.880527         80.131705        7.0  58a781ba7f079f2fd3b86cfe
# 201          2.055822        603.257097       77.0  58a782087f079f2fd3b86dc7
# 1420         2.109832         14.829795        2.0  58a7834a7f079f2fd3b8728c
# 2073         1.872439        108.184064        9.0  58a784037f079f2fd3b87519
# 2328         1.882632        153.899446       14.0  58a7847f7f079f2fd3b87619
# 2343         1.814370         56.513197        3.0  58a784847f079f2fd3b87628

# %%
display(bl_pred_0[bl_pred_0['name']=='NiO'])
# Out:
#       name worst_predicted_bond  expected_distance  actual_distance  \
# 1420   NiO                 Ni-O               1.95         2.109832
# 38479  NiO                 Ni-O               1.95         2.102112
#
#        predicted_volume  num_atoms                       _id
# 1420          14.829795        2.0  58a7834a7f079f2fd3b8728c
# 38479         29.660130        4.0  58a79e087f079f2fd3b9035e

# %%
import multiprocessing as mp
import threading

# %%
# pool = mp.Pool(processes=4)
# results = [pool.apply(FUNCTION, args=(STRUCTURE,)) for x in range(1,7)]
# print(results)

# results = pool.map(cube, range(1,7))
# print(results)

def print_hi(cursor):
    id_endings = []
    for doc in cursor:
        id_endings.append(str(doc['_id'])[-1])
        
    print set(id_endings)

cursors = db.mp_final.parallel_scan(8)
threads = [
    threading.Thread(target=print_hi, args=(cursor,))
    for cursor in cursors]

for thread in threads:
    thread.start()
    
for thread in threads:
    thread.join()
# Out:
# set(['a', 'c', 'b', 'e', 'd', 'f', '1', '0', '3', '2', '5', '4', '7', '6', '9', '8'])

# %%
doc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-49995c85be6f> in <module>()
# ----> 1 doc
#
# NameError: name 'doc' is not defined

# %%
cursor = db.mp_final.find()
cursor.count()
# Out:
# 67483

# %%
batch_num = 0
batch_size = 10
cursor.limit(95)

# %%
# pool = mp.Pool(processes=4)
cursor_set = []
while (batch_num*batch_size) < cursor.count():
    c = cursor.clone().skip(batch_num*batch_size).limit(batch_size)
    cursor_set.append(c)
    batch_num += 1
    
# results = [pool.apply(print_obj_id, args=(c,)) for c in cursor_set]
# print 'obj_ids',

# %%
def get_obj_ids(curs):
    out = []
    for doc in curs:
        out.append[doc['_id']]
    return out

pool = mp.Pool(processes=4)
results = [pool.apply(get_obj_ids, args=(c,)) for c in cursor_set]
print results
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-768a239629af> in <module>()
#       6
#       7 pool = mp.Pool(processes=4)
# ----> 8 results = [pool.apply(get_obj_ids, args=(c,)) for c in cursor_set]
#       9 print results
#
# /Users/sayan/miniconda2/envs/py2/lib/python2.7/multiprocessing/pool.pyc in apply(self, func, args, kwds)
#     242         '''
#     243         assert self._state == RUN
# --> 244         return self.apply_async(func, args, kwds).get()
#     245
#     246     def map(self, func, iterable, chunksize=None):
#
# /Users/sayan/miniconda2/envs/py2/lib/python2.7/multiprocessing/pool.pyc in get(self, timeout)
#     565             return self._value
#     566         else:
# --> 567             raise self._value
#     568
#     569     def _set(self, i, obj):
#
# TypeError: can't pickle thread.lock objects

# %%
i=0
for doc in cursor:
    i+=1
    print i, doc['_id']
# Out:
# 1 58a781ba7f079f2fd3b86cfe
# 2 58a781bb7f079f2fd3b86cff
# 3 58a781bc7f079f2fd3b86d00
# 4 58a781bc7f079f2fd3b86d01
# 5 58a781bd7f079f2fd3b86d02
# 6 58a781bd7f079f2fd3b86d03
# 7 58a781bd7f079f2fd3b86d04
# 8 58a781be7f079f2fd3b86d05
# 9 58a781be7f079f2fd3b86d06
# 10 58a781bf7f079f2fd3b86d07

# %%
cursor_clone = cursor.clone()

# %%
i=0
for doc in cursor_clone:
    i+=1
    print i, doc['_id']
# Out:
# 1 58a781ba7f079f2fd3b86cfe
# 2 58a781bb7f079f2fd3b86cff
# 3 58a781bc7f079f2fd3b86d00
# 4 58a781bc7f079f2fd3b86d01
# 5 58a781bd7f079f2fd3b86d02
# 6 58a781bd7f079f2fd3b86d03
# 7 58a781bd7f079f2fd3b86d04
# 8 58a781be7f079f2fd3b86d05
# 9 58a781be7f079f2fd3b86d06
# 10 58a781bf7f079f2fd3b86d07

# %%
cursor.alive
# Out:
# False

# %%
Structure.from_dict(doc)
# Out:
# Structure Summary
# Lattice
#     abc : 5.1165439476774068 10.321597155914025 9.9088226497680711
#  angles : 16.258432635698291 29.376595063230173 33.220824340184052
#  volume : 71.868569702060682
#       A : 2.5056169399999999 0.0 4.4610431200000003
#       B : -0.0095372100000000008 2.8897407400000001 9.9088180599999998
#       C : -0.0095372100000000008 0.0 9.9088180599999998
# PeriodicSite: Ni (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
# PeriodicSite: Ni (1.2480, 0.0000, 7.1849) [0.5000, 0.0000, 0.5000]
# PeriodicSite: Ni (-0.0048, 1.4449, 4.9544) [0.0000, 0.5000, 0.0000]
# PeriodicSite: O (0.5115, 0.0000, 3.8357) [0.2053, 0.0000, 0.2947]
# PeriodicSite: O (0.7933, 1.4449, 8.6276) [0.3194, 0.5000, 0.2269]
# PeriodicSite: O (1.9846, 0.0000, 10.5341) [0.7947, 0.0000, 0.7053]
# PeriodicSite: O (1.6932, 1.4449, 15.6510) [0.6806, 0.5000, 0.7731]
